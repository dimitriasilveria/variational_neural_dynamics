# %% [markdown]
# # Continual Policy Learning via Variational Neural Dynamics
#
# This notebook implements the complete two-stage loop from Algorithm 1 of *Continual Robot Policy Learning via Variational Neural Dynamics* for state-based quadrotor hovering:
#
# 1. collect disturbed deployment rollouts with the latest policy and live encoder;
# 2. append non-overlapping latent groups to an accumulated replay buffer and jointly update the encoder, residual model, and auxiliary decoder;
# 3. freeze those models, sample one standard-normal latent per simulated environment, hold it fixed for a complete rollout, and update the latent-conditioned policy by BPTT through `f_prior + D_psi`;
# 4. repeat.
#
# The CSV latent paired with each wind is never used. Wind labels are not inputs to either network.

# %%
import importlib
import os
import time
import numpy as np

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"

import jax
import jax.numpy as jnp
import optax
from flax.core import freeze, unfreeze
from flax.training.train_state import TrainState
from jax.scipy.spatial.transform import Rotation
from matplotlib import pyplot as plt
from orbax.checkpoint import PyTreeCheckpointer

try:
    import wandb
except ModuleNotFoundError:
    wandb = None

from lotf import LOTF_PATH
from lotf.envs import HoveringStateEnv
from lotf.envs.wrappers import MinMaxObservationWrapper
from lotf.modules import (
    LatentConditionedResidualDynamics,
    MLP,
    RecurrentTrajectoryEncoder,
)
from lotf.objects import Quadrotor
import lotf.objects.group_replay_buffer as group_replay_buffer_module

# Reload local buffer edits when this notebook is rerun in a live kernel.
group_replay_buffer_module = importlib.reload(
    group_replay_buffer_module
)
GroupReplayBuffer = group_replay_buffer_module.GroupReplayBuffer
from lotf.utils.pytrees import tree_select

# %matplotlib inline

# %% [markdown]
# ## 1. Reproducibility and tunable continual-learning schedule
#
# The defaults below preserve the requested 100 dynamics updates and 1,000 alternating rounds. The paper reports 512 parallel environments and 250 steps (5 s) for hovering policy BPTT. `policy_updates_per_round` is deliberately separate: setting it to 1 means one BPTT optimizer update per continual round; set it to 1500 to reproduce the paper's reported standalone hovering policy-optimization length for every improvement stage.
#
# The paper specifies the reward weights and functional form, but does not publish a quadrotor-specific numerical discount, policy learning rate, Huber delta, collision magnitude, or universal VND loss weights. Those quantities remain explicit below. `policy_discount=1` and `reward_huber_delta=1` match the repository's existing undiscounted BPTT and smooth-L1 convention. The BPTT hovering reward intentionally replaces the paper's height-only term with full three-dimensional position error so that policy refinement preserves lateral target regulation.
#
# Live monitoring uses Weights & Biases. Before running this section for the first time, install it in the notebook kernel with `%pip install wandb`, restart the kernel, and run `wandb login`. Set `wandb_mode = "offline"` below when a network connection is unavailable; the run can then be synchronized later with `wandb sync`.
#
# One repository constraint is intentionally preserved: the supplied base-policy checkpoint consumes the environment's 9-value rotation-matrix observation, whereas supplement A.7 describes a quaternion task observation. Changing that interface would make the checkpoint's first Dense layer incompatible and would require base-policy retraining. The VND context itself still uses the paper's `(p, q, v, a)` representation.

# %%
seed = 10
master_key = jax.random.key(seed)


def experiment_key(stream_id):
    return jax.random.fold_in(master_key, stream_id)


# Continual loop.
num_continual_rounds = 10000
rollouts_per_collection_round = 256
max_collection_attempts_per_round = 10
dynamics_updates_per_round = 500
checkpoint_every_rounds = 25
initialize_vnd_from_pretrained_checkpoint = True
pretrained_vnd_checkpoint_name = "state_hovering_complete_mmd"
# The old replay samples/counts were not stored in that checkpoint, so
# replacing its statistics with one new collection would miscalibrate it.
update_normalization_from_continual_buffer = False

# Shared-context VND dataset.
context_length = 20
dynamics_horizon = 110
latent_dim = 12
state_action_dim = 14
residual_dim = 6  # Hovering wind changes position/velocity, not orientation.
replay_batch_size = 128
prior_evaluation_batch_size = 2048

# Joint encoder/residual optimization.
dynamics_learning_rate = 3e-4
lambda_rec = 1e-7
lambda_mmd_max = 1e-5
mmd_kernel_sigma = 2.0
mmd_warmup_updates = 800
mmd_ramp_updates = 2500
residual_huber_delta = 1.0

# Paper-style differentiable policy improvement.
policy_num_envs = 512
policy_updates_per_round = 1
policy_rollout_horizon = 250
policy_learning_rate = 1e-3
policy_discount = 1.0
reward_huber_delta = 1.0

# Simulation and collection.
sim_dt = 0.02
control_delay = 0.04
max_sim_time = policy_rollout_horizon * sim_dt
hover_target = jnp.array([1.5, 0.0, 1.5], dtype=jnp.float32)
collection_thrust_excitation_fraction = 0.03
collection_body_rate_excitation_bound = jnp.array(
    [0.12, 0.12, 0.12], dtype=jnp.float32
)

assert context_length == 20
assert dynamics_horizon > 0
assert context_length + dynamics_horizon <= policy_rollout_horizon
assert policy_rollout_horizon == int(round(max_sim_time / sim_dt))
assert mmd_kernel_sigma == 2.0
assert policy_num_envs > 0 and policy_updates_per_round > 0

# Live experiment monitoring. Set enable_wandb=False to disable it.
enable_wandb = True
wandb_project = "continual-vnd-state-hovering"
wandb_entity = None
wandb_run_name = None
wandb_mode = "online"  # Use "offline" when disconnected.
wandb_dynamics_log_every = 25
wandb_histogram_every_rounds = 10
assert wandb_dynamics_log_every > 0

if enable_wandb and wandb is None:
    raise ModuleNotFoundError(
        "Weights & Biases is not installed in this kernel. Run "
        "`%pip install wandb`, restart the kernel, then run "
        "`wandb login`; or set enable_wandb=False."
    )

wandb_run = None
if enable_wandb:
    wandb_run = wandb.init(
        project=wandb_project,
        entity=wandb_entity,
        name=wandb_run_name,
        mode=wandb_mode,
        config={
            "seed": seed,
            "num_continual_rounds": num_continual_rounds,
            "rollouts_per_collection_round": rollouts_per_collection_round,
            "dynamics_updates_per_round": dynamics_updates_per_round,
            "context_length": context_length,
            "dynamics_horizon": dynamics_horizon,
            "latent_dim": latent_dim,
            "replay_batch_size": replay_batch_size,
            "dynamics_learning_rate": dynamics_learning_rate,
            "lambda_rec": lambda_rec,
            "lambda_mmd_max": lambda_mmd_max,
            "mmd_kernel_sigma": mmd_kernel_sigma,
            "mmd_warmup_updates": mmd_warmup_updates,
            "mmd_ramp_updates": mmd_ramp_updates,
            "residual_huber_delta": residual_huber_delta,
            "policy_num_envs": policy_num_envs,
            "policy_updates_per_round": policy_updates_per_round,
            "policy_rollout_horizon": policy_rollout_horizon,
            "policy_learning_rate": policy_learning_rate,
            "policy_discount": policy_discount,
            "reward_huber_delta": reward_huber_delta,
            "sim_dt": sim_dt,
            "control_delay": control_delay,
        },
    )
    wandb_run.define_metric("dynamics/update")
    wandb_run.define_metric(
        "dynamics/*", step_metric="dynamics/update"
    )
    wandb_run.define_metric("continual/round")
    for metric_prefix in (
        "policy", "dynamics_round", "replay", "collection",
        "encoder", "parameters", "timing",
    ):
        wandb_run.define_metric(
            f"{metric_prefix}/*", step_metric="continual/round"
        )
    print(f"W&B run: {wandb_run.url or wandb_run.id}")
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/dimitria/.netrc.
# wandb: Currently logged in as: dimitriasilveria-ds (dimitriasilveria-ds-queen-s-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.29.0
# Run data is saved locally in <code>/home/dimitria/PhD_codes/learning_on_the_fly/examples/state_hovering/wandb/run-20260827_150702-9se4i1bn</code>
# Syncing run <strong><a href='https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering/runs/9se4i1bn' target="_blank">astral-lion-5</a></strong> to <a href='https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering' target="_blank">https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering</a>
#  View run at <a href='https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering/runs/9se4i1bn' target="_blank">https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering/runs/9se4i1bn</a>
# W&B run: https://wandb.ai/dimitriasilveria-ds-queen-s-university/continual-vnd-state-hovering/runs/9se4i1bn

# %% [markdown]
# ## 2. Nominal and disturbed environments
#
# The deployment environment applies the true episode-level wind acceleration. The differentiable policy environment is left nominal; its successor is corrected explicitly by the frozen learned residual. Both retain the original 0.04 s action delay.

# %%
nominal_dynamics_configuration = {
    "use_high_fidelity": False,
    "use_forward_residual": False,
}

deployment_env = HoveringStateEnv(
    max_steps_in_episode=policy_rollout_horizon,
    dt=sim_dt,
    delay=control_delay,
    quad_obj=Quadrotor.from_name(
        "example_quad", nominal_dynamics_configuration
    ),
    margin=0.5,
    hover_target=hover_target,
    apply_hidden_acceleration=True,
)
deployment_env = MinMaxObservationWrapper(deployment_env)

policy_sim_env = HoveringStateEnv(
    max_steps_in_episode=policy_rollout_horizon,
    dt=sim_dt,
    delay=control_delay,
    quad_obj=Quadrotor.from_name(
        "example_quad", nominal_dynamics_configuration
    ),
    margin=0.5,
    hover_target=hover_target,
    apply_hidden_acceleration=False,
)
policy_sim_env = MinMaxObservationWrapper(policy_sim_env)

action_dim = deployment_env.action_space.shape[0]
obs_dim = deployment_env.observation_space.shape[0]
dummy_residual_params = {}

collection_action_excitation_bound = jnp.concatenate([
    (
        collection_thrust_excitation_fraction
        * deployment_env.hovering_action[0]
    )[None],
    collection_body_rate_excitation_bound,
])

print("Environment configuration")
print(f"  observation dimension: {obs_dim}")
print(f"  action dimension:      {action_dim}")
print(f"  control delay:         {control_delay:.3f} s")
print(f"  rollout duration:      {max_sim_time:.2f} s")
print(f"  action excitation:     {collection_action_excitation_bound}")
# Out:
# Environment configuration
#   observation dimension: 27
#   action dimension:      4
#   control delay:         0.040 s
#   rollout duration:      5.00 s
#   action excitation:     [0.0565056 0.12      0.12      0.12     ]

# %% [markdown]
# ## 3. Load the base policy and add the latent input without changing its initial behavior
#
# The loaded policy has observation-only input. The continual policy has input `[normalized task observation, z]`. Its observation rows and all later layers are copied exactly from the checkpoint, while the new latent rows of the first kernel are initialized to zero. Consequently, the first deployment round uses exactly the previously trained policy for every latent.

# %%
policy_name = "state_hovering_params"
policy_checkpoint_path = os.path.abspath(os.path.join(
    LOTF_PATH, "..", "checkpoints", "policy", policy_name
))
checkpointer = PyTreeCheckpointer()
base_policy_params = checkpointer.restore(policy_checkpoint_path)

base_policy_net = MLP(
    [obs_dim, 512, 512, action_dim],
    initial_scale=0.01,
    action_bias=deployment_env.hovering_action,
)
latent_policy_net = MLP(
    [obs_dim + latent_dim, 512, 512, action_dim],
    initial_scale=0.01,
    action_bias=deployment_env.hovering_action,
)

expanded_policy_params = unfreeze(
    latent_policy_net.initialize(experiment_key(10))
)
loaded_policy_params = unfreeze(base_policy_params)

assert tuple(expanded_policy_params["params"]) == tuple(
    loaded_policy_params["params"]
)
for layer_name in loaded_policy_params["params"]:
    if layer_name == "Dense_0":
        old_kernel = loaded_policy_params["params"][layer_name]["kernel"]
        new_kernel = expanded_policy_params["params"][layer_name]["kernel"]
        assert old_kernel.shape == (obs_dim, 512)
        assert new_kernel.shape == (obs_dim + latent_dim, 512)
        expanded_policy_params["params"][layer_name]["kernel"] = (
            new_kernel.at[:obs_dim].set(old_kernel).at[obs_dim:].set(0.0)
        )
        expanded_policy_params["params"][layer_name]["bias"] = (
            loaded_policy_params["params"][layer_name]["bias"]
        )
    else:
        expanded_policy_params["params"][layer_name] = (
            loaded_policy_params["params"][layer_name]
        )

expanded_policy_params = freeze(expanded_policy_params)
policy_train_state = TrainState.create(
    apply_fn=latent_policy_net.apply,
    params=expanded_policy_params,
    tx=optax.adam(policy_learning_rate),
)

policy_equivalence_obs = jnp.zeros((4, obs_dim), dtype=jnp.float32)
policy_equivalence_z = jax.random.normal(
    experiment_key(11), (4, latent_dim)
)
base_actions = base_policy_net.apply(
    base_policy_params, policy_equivalence_obs
)
expanded_actions = latent_policy_net.apply(
    policy_train_state.params,
    jnp.concatenate([policy_equivalence_obs, policy_equivalence_z], axis=-1),
)
assert jnp.allclose(base_actions, expanded_actions, atol=1e-6)
print(f"Loaded base policy from {policy_checkpoint_path}")
print("Latent-conditioned policy initially reproduces it exactly.")
# Out:
# /home/dimitria/venvs/diff-sim-env/lib/python3.12/site-packages/orbax/checkpoint/type_handlers.py:1330: UserWarning: Couldn't find sharding info under RestoreArgs. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file instead of directly from RestoreArgs. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(
# Loaded base policy from /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/policy/state_hovering_params
# Latent-conditioned policy initially reproduces it exactly.

# %% [markdown]
# ## 4. Create the architecture and restore the pretrained VND model
#
# The GRU encoder uses a 128-D projection and hidden state. The shared residual backbone has 256 hidden units, two FiLM-conditioned blocks, and separate position and velocity heads. One latent is broadcast across all `dynamics_horizon` transitions assigned to its context. By default, the encoder, residual model, auxiliary decoder, and all normalization statistics are restored together from `state_hovering_complete_mmd`; Adam starts with a fresh optimizer state.

# %%
trajectory_encoder = RecurrentTrajectoryEncoder(
    state_action_dim=state_action_dim,
    context_length=context_length,
    latent_dim=latent_dim,
    projection_dim=128,
    hidden_dim=128,
)
residual_model = LatentConditionedResidualDynamics(
    state_action_dim=state_action_dim,
    latent_dim=latent_dim,
    hidden_dim=256,
    num_blocks=2,
    predict_orientation=False,
)
context_decoder = MLP(
    [latent_dim, 256, 256, context_length * state_action_dim],
    nonlinearity=jax.nn.gelu,
)

key_encoder, key_residual, key_decoder = jax.random.split(
    experiment_key(20), 3
)
random_initial_joint_params = {
    "encoder": trajectory_encoder.initialize(key_encoder),
    "residual": residual_model.initialize(key_residual),
    "decoder": context_decoder.initialize(key_decoder),
}

pretrained_vnd_checkpoint = None
pretrained_vnd_completed_updates = 0
if initialize_vnd_from_pretrained_checkpoint:
    pretrained_vnd_checkpoint_path = os.path.abspath(os.path.join(
        LOTF_PATH,
        "..",
        "checkpoints",
        "residual_dynamics",
        pretrained_vnd_checkpoint_name,
    ))
    pretrained_vnd_checkpoint = PyTreeCheckpointer().restore(
        pretrained_vnd_checkpoint_path
    )
    pretrained_configuration = pretrained_vnd_checkpoint["configuration"]
    expected_configuration = {
        "context_length": context_length,
        "dynamics_horizon": dynamics_horizon,
        "state_action_dim": state_action_dim,
        "latent_dim": latent_dim,
    }
    for name, expected_value in expected_configuration.items():
        restored_value = int(jax.device_get(
            pretrained_configuration[name]
        ))
        if restored_value != expected_value:
            raise ValueError(
                f"Pretrained {name}={restored_value}, but the continual "
                f"notebook requires {expected_value}"
            )
    if set(pretrained_vnd_checkpoint["params"]) != {
        "encoder", "residual", "decoder"
    }:
        raise ValueError(
            "Pretrained checkpoint must contain encoder, residual, "
            "and decoder parameter groups"
        )
    initial_joint_params = pretrained_vnd_checkpoint["params"]
    startup_input_mean = pretrained_vnd_checkpoint["input_mean"]
    startup_input_std = pretrained_vnd_checkpoint["input_std"]
    startup_residual_target_mean = (
        pretrained_vnd_checkpoint["residual_target_mean"]
    )
    startup_residual_target_std = (
        pretrained_vnd_checkpoint["residual_target_std"]
    )
    pretrained_vnd_completed_updates = int(jax.device_get(
        pretrained_configuration.get(
            "num_training_steps", jnp.asarray(0)
        )
    ))
    print("Loaded pretrained encoder, residual, decoder, and statistics:")
    print(f"  {pretrained_vnd_checkpoint_path}")
    print(
        f"  continuing MMD schedule from dynamics update "
        f"{pretrained_vnd_completed_updates:,}"
    )
else:
    initial_joint_params = random_initial_joint_params
    startup_input_mean = jnp.zeros(
        (state_action_dim,), dtype=jnp.float32
    )
    startup_input_std = jnp.ones(
        (state_action_dim,), dtype=jnp.float32
    )
    startup_residual_target_mean = jnp.zeros(
        (residual_dim,), dtype=jnp.float32
    )
    startup_residual_target_std = jnp.ones(
        (residual_dim,), dtype=jnp.float32
    )


def joint_forward(params, contexts, normalized_dynamics_inputs):
    latents = trajectory_encoder.apply(params["encoder"], contexts)
    expanded_latents = jnp.broadcast_to(
        latents[..., None, :],
        normalized_dynamics_inputs.shape[:-1] + (latent_dim,),
    )
    normalized_residuals = residual_model.apply(
        params["residual"],
        normalized_dynamics_inputs,
        expanded_latents,
    )
    reconstructed_contexts = context_decoder.apply(
        params["decoder"], latents
    ).reshape(contexts.shape)
    return latents, normalized_residuals, reconstructed_contexts


joint_train_state = TrainState.create(
    apply_fn=joint_forward,
    params=initial_joint_params,
    tx=optax.adam(dynamics_learning_rate),
)
# Out:
# Loaded pretrained encoder, residual, decoder, and statistics:
#   /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/residual_dynamics/state_hovering_complete_mmd
#   continuing MMD schedule from dynamics update 100,000
# /home/dimitria/venvs/diff-sim-env/lib/python3.12/site-packages/orbax/checkpoint/type_handlers.py:1330: UserWarning: Couldn't find sharding info under RestoreArgs. Populating sharding info from sharding file. Please note restoration time will be slightly increased due to reading from file instead of directly from RestoreArgs. Note also that this option is unsafe when restoring on a different topology than the checkpoint was saved with.
#   warnings.warn(

# %% [markdown]
# ## 5. State representation, normalization, and accumulated replay buffer
#
# The replay buffer stores raw contexts, raw dynamics inputs, and physical residual targets. Every sampled old context is re-encoded with the latest encoder parameters. Because the pretrained checkpoint does not contain the original replay samples or sufficient statistics, its matched input/target statistics remain fixed by default; set `update_normalization_from_continual_buffer=True` only if deliberately replacing them with statistics from the new buffer. Position and velocity inputs are clipped to `[-5, 5]` only after normalization.

# %%
def state_vector_from_env_state(env_state):
    quaternion_xyzw = Rotation.from_matrix(
        env_state.quadrotor_state.R
    ).as_quat()
    quaternion_wxyz = jnp.concatenate(
        [quaternion_xyzw[..., 3:], quaternion_xyzw[..., :3]], axis=-1
    )
    return jnp.concatenate([
        env_state.quadrotor_state.p,
        quaternion_wxyz,
        env_state.quadrotor_state.v,
    ], axis=-1)


def normalize_state_actions(raw_state_actions, input_mean, input_std):
    normalized = (raw_state_actions - input_mean) / input_std
    normalized = normalized.at[..., 0:3].set(
        jnp.clip(normalized[..., 0:3], -5.0, 5.0)
    )
    normalized = normalized.at[..., 7:10].set(
        jnp.clip(normalized[..., 7:10], -5.0, 5.0)
    )
    return normalized


replay_buffer = GroupReplayBuffer(
    context_length=context_length,
    dynamics_horizon=dynamics_horizon,
    state_action_dim=state_action_dim,
    residual_dim=residual_dim,
)

# %% [markdown]
# ## 6. Stage 1A — collect rollouts with the latest policy and live encoder
#
# Before the first complete context exists, the latent is zero. Thereafter the encoder consumes the rolling 20-step normalized state-action window. Small bounded action excitation is applied only during deployment-data collection. The true wind stays constant for each rollout, while the CSV's preassigned latent is ignored.

# %%
@jax.jit
def collect_deployment_rollouts(
    policy_params,
    joint_params,
    input_mean,
    input_std,
    collection_key,
):
    key_reset, key_scan = jax.random.split(collection_key)
    reset_keys = jax.random.split(
        key_reset, rollouts_per_collection_round
    )
    initial_states, initial_observations = jax.vmap(
        lambda reset_key: deployment_env.reset(reset_key)
    )(reset_keys)
    initial_contexts = jnp.zeros(
        (
            rollouts_per_collection_round,
            context_length,
            state_action_dim,
        ),
        dtype=jnp.float32,
    )

    def collection_step(carry, step_key):
        env_states, observations, contexts, context_count = carry
        key_excitation, key_environment = jax.random.split(step_key)

        encoded_latents = trajectory_encoder.apply(
            joint_params["encoder"], contexts
        )
        policy_latents = jnp.where(
            context_count >= context_length,
            encoded_latents,
            jnp.zeros_like(encoded_latents),
        )
        policy_inputs = jnp.concatenate(
            [observations, policy_latents], axis=-1
        )
        nominal_actions = latent_policy_net.apply(
            policy_params, policy_inputs
        )
        excitation = jax.random.uniform(
            key_excitation,
            shape=nominal_actions.shape,
            minval=-collection_action_excitation_bound,
            maxval=collection_action_excitation_bound,
        )
        actions = jnp.clip(
            nominal_actions + excitation,
            deployment_env.action_space.low,
            deployment_env.action_space.high,
        )

        step_keys = jax.random.split(
            key_environment, rollouts_per_collection_round
        )
        transitions = jax.vmap(
            lambda state, action, key: deployment_env._step(
                state, action, dummy_residual_params, key
            )
        )(env_states, actions, step_keys)

        raw_state_actions = jnp.concatenate(
            [state_vector_from_env_state(env_states), actions], axis=-1
        )
        normalized_state_actions = normalize_state_actions(
            raw_state_actions, input_mean, input_std
        )
        next_contexts = jnp.roll(contexts, shift=-1, axis=1)
        next_contexts = next_contexts.at[:, -1, :].set(
            normalized_state_actions
        )
        done = jnp.logical_or(
            transitions.terminated, transitions.truncated
        )
        next_carry = (
            transitions.state,
            transitions.obs,
            next_contexts,
            context_count + 1,
        )
        outputs = (transitions.state, actions, done)
        return next_carry, outputs

    scan_keys = jax.random.split(key_scan, policy_rollout_horizon)
    _, (successor_states, actions, done) = jax.lax.scan(
        collection_step,
        (
            initial_states,
            initial_observations,
            initial_contexts,
            jnp.asarray(0, dtype=jnp.int32),
        ),
        scan_keys,
    )
    time_major_states = jax.tree.map(
        lambda initial, successors: jnp.concatenate(
            [initial[None], successors], axis=0
        ),
        initial_states,
        successor_states,
    )
    rollout_states = jax.tree.map(
        lambda leaf: jnp.swapaxes(leaf, 0, 1), time_major_states
    )
    return rollout_states, jnp.swapaxes(actions, 0, 1), jnp.swapaxes(done, 0, 1)

# %% [markdown]
# ## 7. Stage 1B — construct non-overlapping groups and append them to the buffer
#
# For each rollout, a valid context encodes one latent for up to `dynamics_horizon` following target transitions. Group starts advance by exactly `dynamics_horizon`, so no target transition is assigned to two latent codes. A terminal group is retained whenever its context and at least one following transition are valid; unavailable targets are padded only for static shapes and excluded by a replayed boolean mask. Nominal successors use the same initial simulator state, recorded action, delay buffer, and `_step` implementation as collection.

# %%
@jax.jit
def evaluate_nominal_prior_batch(states, actions, keys):
    return jax.vmap(
        lambda state, action, key: policy_sim_env._env._step(
            state, action, dummy_residual_params, key
        ).state.quadrotor_state
    )(states, actions, keys)


def build_groups_from_collection(
    rollout_states, rollout_actions, rollout_done, prior_key
):
    num_rollouts = rollout_actions.shape[0]
    num_steps = rollout_actions.shape[1]
    current_states = jax.tree.map(
        lambda leaf: leaf[:, :-1], rollout_states
    )
    observed_successors = jax.tree.map(
        lambda leaf: leaf[:, 1:], rollout_states.quadrotor_state
    )
    raw_state_actions = jnp.concatenate([
        state_vector_from_env_state(current_states), rollout_actions
    ], axis=-1)
    assert raw_state_actions.shape == (
        num_rollouts, num_steps, state_action_dim
    )

    flat_current_states = jax.tree.map(
        lambda leaf: leaf.reshape((-1,) + leaf.shape[2:]), current_states
    )
    flat_actions = rollout_actions.reshape(-1, action_dim)
    num_transitions = flat_actions.shape[0]
    flat_prior_keys = jax.random.split(prior_key, num_transitions)
    num_padded = (
        (num_transitions + prior_evaluation_batch_size - 1)
        // prior_evaluation_batch_size
        * prior_evaluation_batch_size
    )
    padding_indices = jnp.minimum(
        jnp.arange(num_padded), num_transitions - 1
    )
    padded_states = jax.tree.map(
        lambda leaf: leaf[padding_indices], flat_current_states
    )
    padded_actions = flat_actions[padding_indices]
    padded_keys = flat_prior_keys[padding_indices]

    nominal_chunks = []
    for start in range(0, num_padded, prior_evaluation_batch_size):
        stop = start + prior_evaluation_batch_size
        nominal_chunks.append(evaluate_nominal_prior_batch(
            jax.tree.map(lambda leaf: leaf[start:stop], padded_states),
            padded_actions[start:stop],
            padded_keys[start:stop],
        ))
    nominal_successors = jax.tree.map(
        lambda *chunks: jnp.concatenate(chunks, axis=0)[:num_transitions],
        *nominal_chunks,
    )
    nominal_successors = jax.tree.map(
        lambda leaf: leaf.reshape(
            (num_rollouts, num_steps) + leaf.shape[1:]
        ),
        nominal_successors,
    )
    residual_targets = jnp.concatenate([
        observed_successors.p - nominal_successors.p,
        observed_successors.v - nominal_successors.v,
    ], axis=-1)

    valid_transition = (
        jnp.cumsum(rollout_done, axis=1) - rollout_done
    ) == 0
    num_candidate_groups = (
        num_steps - context_length + dynamics_horizon - 1
    ) // dynamics_horizon
    if num_candidate_groups <= 0:
        raise ValueError(
            "Need at least context_length + 1 rollout steps"
        )
    group_starts = jnp.arange(num_candidate_groups) * dynamics_horizon
    context_indices = (
        group_starts[:, None] + jnp.arange(context_length)[None, :]
    )
    unbounded_target_indices = (
        group_starts[:, None]
        + context_length
        + jnp.arange(dynamics_horizon)[None, :]
    )
    target_exists = unbounded_target_indices < num_steps
    target_indices = jnp.minimum(unbounded_target_indices, num_steps - 1)
    existing_target_indices = unbounded_target_indices[target_exists]
    assert jnp.unique(existing_target_indices).size == (
        existing_target_indices.size
    )

    grouped_contexts = raw_state_actions[:, context_indices]
    grouped_inputs = raw_state_actions[:, target_indices]
    grouped_targets = residual_targets[:, target_indices]
    context_is_valid = valid_transition[:, context_indices].all(axis=-1)
    grouped_target_masks = (
        valid_transition[:, target_indices]
        & target_exists[None, :, :]
    )
    valid_groups = context_is_valid & grouped_target_masks.any(axis=-1)
    return (
        grouped_contexts[valid_groups],
        grouped_inputs[valid_groups],
        grouped_targets[valid_groups],
        grouped_target_masks[valid_groups],
    )

# %% [markdown]
# ## 8. Stage 1C — joint VND update with a fixed prior bank
#
# `fixed_prior_bank` is sampled in Stage 2 and reused for every dynamics update in the next Stage 1. The first Stage 1 receives one reproducible standard-normal bank. No standard-normal vectors are sampled inside the dynamics optimizer. Old contexts are sampled from the accumulated raw buffer and re-encoded with current encoder parameters on every visit.

# %%
def biased_rbf_mmd(encoded_latents, prior_latents):
    def kernel(left, right):
        left_norm = jnp.sum(jnp.square(left), axis=-1)[:, None]
        right_norm = jnp.sum(jnp.square(right), axis=-1)[None, :]
        squared_distance = jnp.maximum(
            left_norm + right_norm - 2.0 * (left @ right.T), 0.0
        )
        return jnp.exp(
            -squared_distance / (2.0 * mmd_kernel_sigma**2)
        )

    return (
        kernel(encoded_latents, encoded_latents).mean()
        + kernel(prior_latents, prior_latents).mean()
        - 2.0 * kernel(encoded_latents, prior_latents).mean()
    )


def mmd_weight_at_update(update_index):
    ramp_fraction = jnp.clip(
        (update_index - mmd_warmup_updates) / mmd_ramp_updates,
        0.0,
        1.0,
    )
    return lambda_mmd_max * ramp_fraction


def joint_vnd_loss(
    params,
    raw_contexts,
    raw_dynamics_inputs,
    raw_targets,
    raw_target_masks,
    prior_latents,
    input_mean,
    input_std,
    target_mean,
    target_std,
    mmd_weight,
):
    normalized_contexts = normalize_state_actions(
        raw_contexts, input_mean, input_std
    )
    normalized_dynamics_inputs = normalize_state_actions(
        raw_dynamics_inputs, input_mean, input_std
    )
    normalized_targets = (raw_targets - target_mean) / target_std
    latents, normalized_predictions, reconstructed_contexts = joint_forward(
        params, normalized_contexts, normalized_dynamics_inputs
    )
    per_component_dynamics_loss = optax.huber_loss(
        normalized_predictions,
        normalized_targets,
        delta=residual_huber_delta,
    )
    per_transition_dynamics_loss = per_component_dynamics_loss.mean(
        axis=-1
    )
    target_mask_weights = raw_target_masks.astype(
        per_transition_dynamics_loss.dtype
    )
    valid_targets_per_group = jnp.maximum(
        target_mask_weights.sum(axis=-1), 1.0
    )
    dynamics_loss = jnp.mean(
        (per_transition_dynamics_loss * target_mask_weights).sum(axis=-1)
        / valid_targets_per_group
    )
    reconstruction_loss = jnp.sum(
        jnp.square(reconstructed_contexts - normalized_contexts),
        axis=(-2, -1),
    ).mean()
    mmd_loss = biased_rbf_mmd(latents, prior_latents)
    total_loss = (
        dynamics_loss
        + lambda_rec * reconstruction_loss
        + mmd_weight * mmd_loss
    )
    return total_loss, (dynamics_loss, reconstruction_loss, mmd_loss)


@jax.jit
def dynamics_optimizer_step(
    train_state,
    raw_contexts,
    raw_dynamics_inputs,
    raw_targets,
    raw_target_masks,
    prior_latents,
    input_mean,
    input_std,
    target_mean,
    target_std,
    global_update,
):
    mmd_weight = mmd_weight_at_update(global_update)
    (loss, components), gradients = jax.value_and_grad(
        joint_vnd_loss, has_aux=True
    )(
        train_state.params,
        raw_contexts,
        raw_dynamics_inputs,
        raw_targets,
        raw_target_masks,
        prior_latents,
        input_mean,
        input_std,
        target_mean,
        target_std,
        mmd_weight,
    )
    gradient_norm = optax.global_norm(gradients)
    encoder_gradient_norm = optax.global_norm(gradients["encoder"])
    residual_gradient_norm = optax.global_norm(gradients["residual"])
    decoder_gradient_norm = optax.global_norm(gradients["decoder"])
    previous_params = train_state.params
    train_state = train_state.apply_gradients(grads=gradients)
    parameter_updates = jax.tree.map(
        lambda updated, previous: updated - previous,
        train_state.params,
        previous_params,
    )
    update_norm = optax.global_norm(parameter_updates)
    encoder_update_norm = optax.global_norm(parameter_updates["encoder"])
    residual_update_norm = optax.global_norm(parameter_updates["residual"])
    decoder_update_norm = optax.global_norm(parameter_updates["decoder"])
    return train_state, jnp.stack([
        loss, components[0], components[1], components[2], mmd_weight,
        gradient_norm, update_norm,
        encoder_gradient_norm, residual_gradient_norm,
        decoder_gradient_norm, encoder_update_norm,
        residual_update_norm, decoder_update_norm,
    ])


def run_dynamics_stage(
    train_state,
    replay,
    fixed_prior_bank,
    input_mean,
    input_std,
    target_mean,
    target_std,
    first_global_update,
    stage_key,
):
    metrics = []
    for local_update in range(dynamics_updates_per_round):
        global_update = first_global_update + local_update
        batch_key = jax.random.fold_in(stage_key, local_update)
        batch = replay.sample(batch_key, replay_batch_size)
        prior_indices = (
            jnp.arange(replay_batch_size)
            + global_update * replay_batch_size
        ) % fixed_prior_bank.shape[0]
        prior_latents = fixed_prior_bank[prior_indices]
        train_state, update_metrics = dynamics_optimizer_step(
            train_state,
            *batch,
            prior_latents,
            input_mean,
            input_std,
            target_mean,
            target_std,
            jnp.asarray(global_update),
        )
        metrics.append(update_metrics)
        should_log = (
            local_update % wandb_dynamics_log_every == 0
            or local_update == dynamics_updates_per_round - 1
        )
        if wandb_run is not None and should_log:
            host_update_metrics = np.asarray(
                jax.device_get(update_metrics)
            )
            wandb_run.log({
                "dynamics/update": global_update + 1,
                "dynamics/total_loss": host_update_metrics[0],
                "dynamics/L_dyn": host_update_metrics[1],
                "dynamics/L_rec": host_update_metrics[2],
                "dynamics/weighted_L_rec": (
                    lambda_rec * host_update_metrics[2]
                ),
                "dynamics/L_mmd": host_update_metrics[3],
                "dynamics/lambda_mmd": host_update_metrics[4],
                "dynamics/weighted_L_mmd": (
                    host_update_metrics[4] * host_update_metrics[3]
                ),
                "dynamics/gradient_norm": host_update_metrics[5],
                "dynamics/update_norm": host_update_metrics[6],
                "dynamics/encoder_gradient_norm": host_update_metrics[7],
                "dynamics/residual_gradient_norm": host_update_metrics[8],
                "dynamics/decoder_gradient_norm": host_update_metrics[9],
                "dynamics/encoder_update_norm": host_update_metrics[10],
                "dynamics/residual_update_norm": host_update_metrics[11],
                "dynamics/decoder_update_norm": host_update_metrics[12],
            })
    metrics = jnp.stack(metrics)
    metrics.block_until_ready()
    return train_state, metrics

# %% [markdown]
# ## 9. Stage 2 — freeze VND and improve the policy by BPTT
#
# At every policy optimizer update, the notebook samples one independent `z ~ N(0, I)` per parallel environment. That same latent is held fixed throughout the complete 5 s recursive rollout and conditions both the policy and residual model. Gradients are taken only with respect to policy parameters, while still propagating through the frozen residual model's state/action Jacobians.
#
# The reward below uses supplement Eq. (4)'s velocity, body-rate, acceleration, upright-attitude, hover-action, and collision terms and weights, but deliberately replaces the height-only term with a Huber penalty on the complete position-error vector `p - hover_target`. This keeps lateral target regulation in the differentiable policy objective. Continuous errors use Huber penalties on their scalar magnitude. Because the paper does not state a separate numerical collision coefficient, the collision term uses the repository environment's remaining-horizon penalty convention.

# %%
def huber_magnitude(error, delta=reward_huber_delta):
    squared_magnitude = jnp.sum(jnp.square(error), axis=-1)
    safe_magnitude = jnp.sqrt(jnp.maximum(
        squared_magnitude, jnp.finfo(error.dtype).eps
    ))
    return jnp.where(
        squared_magnitude <= delta**2,
        0.5 * squared_magnitude,
        delta * (safe_magnitude - 0.5 * delta),
    )


def huber_scalar(error, delta=reward_huber_delta):
    magnitude = jnp.abs(error)
    quadratic = jnp.minimum(magnitude, delta)
    linear = magnitude - quadratic
    return 0.5 * jnp.square(quadratic) + delta * linear


def upright_huber_cost(r_zz, delta=reward_huber_delta):
    cosine = jnp.clip(r_zz, -1.0, 1.0)
    one_minus_cosine = jnp.maximum(1.0 - cosine, 0.0)
    angle_squared_near_upright = (
        2.0 * one_minus_cosine
        + jnp.square(one_minus_cosine) / 3.0
        + 4.0 * one_minus_cosine**3 / 45.0
    )
    safe_cosine = jnp.clip(cosine, -1.0 + 1e-7, 1.0 - 1e-7)
    angle_squared_regular = jnp.square(jnp.arccos(safe_cosine))
    angle_squared = jnp.where(
        one_minus_cosine < 1e-4,
        angle_squared_near_upright,
        angle_squared_regular,
    )
    safe_angle = jnp.sqrt(jnp.maximum(
        angle_squared, jnp.finfo(r_zz.dtype).eps
    ))
    return jnp.where(
        angle_squared <= delta**2,
        0.5 * angle_squared,
        delta * (safe_angle - 0.5 * delta),
    )


def full_position_hover_reward(
    next_states, commanded_actions, remaining_steps
):
    quad_states = next_states.quadrotor_state
    position_cost = huber_magnitude(quad_states.p - hover_target)
    velocity_cost = huber_magnitude(quad_states.v)
    body_rate_cost = huber_magnitude(quad_states.omega)
    acceleration_cost = huber_magnitude(quad_states.acc)
    attitude_cost = upright_huber_cost(quad_states.R[:, 2, 2])
    action_cost = huber_magnitude(
        commanded_actions - policy_sim_env.hovering_action
    )
    base_cost = (
        position_cost
        + 0.1 * velocity_cost
        + 0.15 * body_rate_cost
        + 0.1 * acceleration_cost
        + 0.1 * attitude_cost
        + action_cost
    )
    collision = jax.vmap(policy_sim_env._env._is_colliding)(next_states)
    collision_indicator = jax.lax.stop_gradient(
        collision.astype(base_cost.dtype)
    )
    collision_cost = collision_indicator * remaining_steps * base_cost
    return -sim_dt * (base_cost + collision_cost)


delay_first_segment = (
    policy_sim_env.delay
    - (policy_sim_env.num_last_actions - 2) * policy_sim_env.dt
)
effective_action_buffer_index = int(delay_first_segment < policy_sim_env.dt)


def corrected_policy_step(
    env_states,
    actions,
    rollout_latents,
    joint_params,
    input_mean,
    input_std,
    target_mean,
    target_std,
    step_keys,
):
    clipped_actions = jnp.clip(
        actions,
        policy_sim_env.action_space.low,
        policy_sim_env.action_space.high,
    )
    nominal_transitions = jax.vmap(
        lambda state, action, key: policy_sim_env._env._step(
            state, action, dummy_residual_params, key
        )
    )(env_states, clipped_actions, step_keys)
    raw_residual_inputs = jnp.concatenate([
        state_vector_from_env_state(env_states), clipped_actions
    ], axis=-1)
    normalized_residual_inputs = normalize_state_actions(
        raw_residual_inputs, input_mean, input_std
    )
    normalized_corrections = residual_model.apply(
        joint_params["residual"],
        normalized_residual_inputs,
        rollout_latents,
    )
    physical_corrections = (
        normalized_corrections * target_std + target_mean
    )

    nominal_states = nominal_transitions.state
    corrected_position = (
        nominal_states.quadrotor_state.p + physical_corrections[:, :3]
    )
    corrected_velocity = (
        nominal_states.quadrotor_state.v + physical_corrections[:, 3:6]
    )
    corrected_acceleration = (
        corrected_velocity - env_states.quadrotor_state.v
    ) / sim_dt
    applied_body_rates = nominal_states.last_actions[
        :, effective_action_buffer_index, 1:
    ]
    corrected_quad_states = nominal_states.quadrotor_state.replace(
        p=corrected_position,
        v=corrected_velocity,
        acc=corrected_acceleration,
        omega=applied_body_rates,
    )
    corrected_states = nominal_states.replace(
        quadrotor_state=corrected_quad_states
    )
    raw_observations = jax.vmap(
        policy_sim_env._env._get_obs
    )(corrected_states)
    normalized_observations = (
        2.0
        * (raw_observations - policy_sim_env._obs_min)
        / (policy_sim_env._obs_max - policy_sim_env._obs_min)
        - 1.0
    )
    return corrected_states, normalized_observations, clipped_actions


def policy_rollout_loss(
    policy_params,
    joint_params,
    input_mean,
    input_std,
    target_mean,
    target_std,
    rollout_key,
):
    key_latents, key_reset, key_steps = jax.random.split(rollout_key, 3)
    rollout_latents = jax.random.normal(
        key_latents, (policy_num_envs, latent_dim)
    )
    reset_keys = jax.random.split(key_reset, policy_num_envs)
    initial_states, initial_observations = jax.vmap(
        lambda reset_key: policy_sim_env.reset(reset_key)
    )(reset_keys)
    scan_keys = jax.random.split(key_steps, policy_rollout_horizon)

    def rollout_step(carry, inputs):
        env_states, observations, active = carry
        step_index, step_key = inputs
        policy_inputs = jnp.concatenate(
            [observations, rollout_latents], axis=-1
        )
        actions = latent_policy_net.apply(policy_params, policy_inputs)
        environment_keys = jax.random.split(step_key, policy_num_envs)
        candidate_states, candidate_observations, clipped_actions = (
            corrected_policy_step(
                env_states,
                actions,
                rollout_latents,
                joint_params,
                input_mean,
                input_std,
                target_mean,
                target_std,
                environment_keys,
            )
        )
        remaining_steps = policy_rollout_horizon - step_index - 1
        unmasked_rewards = full_position_hover_reward(
            candidate_states, clipped_actions, remaining_steps
        )
        rewards = jnp.where(active, unmasked_rewards, 0.0)
        position_error = jnp.where(
            active,
            jnp.linalg.norm(
                candidate_states.quadrotor_state.p - hover_target,
                axis=-1,
            ),
            0.0,
        )
        collision = jax.vmap(
            policy_sim_env._env._is_colliding
        )(candidate_states)
        next_active = active & ~collision
        next_states = jax.vmap(
            lambda is_active, candidate, previous: tree_select(
                is_active, candidate, previous
            )
        )(active, candidate_states, env_states)
        next_observations = jax.vmap(
            lambda is_active, candidate, previous: jax.lax.select(
                is_active, candidate, previous
            )
        )(active, candidate_observations, observations)
        outputs = (rewards, position_error, active)
        return (next_states, next_observations, next_active), outputs

    initial_active = jnp.ones(policy_num_envs, dtype=bool)
    _, (rewards, position_errors, active_steps) = jax.lax.scan(
        jax.checkpoint(rollout_step),
        (initial_states, initial_observations, initial_active),
        (jnp.arange(policy_rollout_horizon), scan_keys),
    )
    discounts = policy_discount ** jnp.arange(policy_rollout_horizon)
    discounted_returns = jnp.sum(
        discounts[:, None] * rewards, axis=0
    )
    loss = -discounted_returns.mean()
    auxiliary = (
        discounted_returns.mean(),
        rewards.sum() / jnp.maximum(active_steps.sum(), 1),
        position_errors.sum() / jnp.maximum(active_steps.sum(), 1),
        rollout_latents,
    )
    return loss, auxiliary


def tree_all_finite(tree):
    checks = [
        jnp.all(jnp.isfinite(leaf)) for leaf in jax.tree.leaves(tree)
    ]
    return jnp.all(jnp.stack(checks))


@jax.jit
def policy_optimizer_step(
    train_state,
    joint_params,
    input_mean,
    input_std,
    target_mean,
    target_std,
    rollout_key,
):
    (loss, auxiliary), gradients = jax.value_and_grad(
        policy_rollout_loss, has_aux=True
    )(
        train_state.params,
        joint_params,
        input_mean,
        input_std,
        target_mean,
        target_std,
        rollout_key,
    )
    gradient_norm = optax.global_norm(gradients)
    previous_params = train_state.params
    candidate_train_state = train_state.apply_gradients(grads=gradients)
    update_applied = (
        jnp.isfinite(loss)
        & tree_all_finite(gradients)
        & tree_all_finite(candidate_train_state.params)
        & tree_all_finite(candidate_train_state.opt_state)
    )
    train_state = jax.lax.cond(
        update_applied,
        lambda _: candidate_train_state,
        lambda _: train_state,
        operand=None,
    )
    update_norm = optax.global_norm(jax.tree.map(
        lambda updated, previous: updated - previous,
        train_state.params,
        previous_params,
    ))
    (
        mean_return, mean_reward, mean_position_error, rollout_latents
    ) = auxiliary
    return (
        train_state,
        loss,
        mean_return,
        mean_reward,
        mean_position_error,
        gradient_norm,
        update_norm,
        update_applied,
        rollout_latents,
    )


def run_policy_stage(
    train_state,
    joint_params,
    input_mean,
    input_std,
    target_mean,
    target_std,
    stage_key,
):
    stage_metrics = []
    sampled_prior_banks = []
    for policy_update in range(policy_updates_per_round):
        update_key = jax.random.fold_in(stage_key, policy_update)
        (
            train_state,
            loss,
            mean_return,
            mean_reward,
            mean_position_error,
            gradient_norm,
            update_norm,
            update_applied,
            rollout_latents,
        ) = policy_optimizer_step(
            train_state,
            joint_params,
            input_mean,
            input_std,
            target_mean,
            target_std,
            update_key,
        )
        stage_metrics.append(jnp.stack([
            loss, mean_return, mean_reward, mean_position_error,
            gradient_norm, update_norm, update_applied.astype(loss.dtype)
        ]))
        sampled_prior_banks.append(rollout_latents)
    metrics = jnp.stack(stage_metrics)
    next_stage_prior_bank = jnp.concatenate(sampled_prior_banks, axis=0)
    metrics.block_until_ready()
    next_stage_prior_bank.block_until_ready()
    return train_state, metrics, next_stage_prior_bank

# %% [markdown]
# ## 10. Checkpointing
#
# Each checkpoint contains both networks' optimizer states, the policy optimizer state, the current normalization statistics, the prior bank that must be reused by the next dynamics stage, and loop counters. Replay data remain in the in-memory accumulated buffer; rerunning from a checkpoint therefore requires separately persisting the deployment data if exact continuation is needed.

# %%
continual_checkpoint_root = os.path.abspath(os.path.join(
    LOTF_PATH,
    "..",
    "checkpoints",
    "continual_vnd",
    "state_hovering_full",
))
os.makedirs(continual_checkpoint_root, exist_ok=True)


def save_continual_checkpoint(
    completed_rounds,
    joint_state,
    policy_state,
    input_mean,
    input_std,
    target_mean,
    target_std,
    fixed_prior_bank,
    global_dynamics_update,
):
    checkpoint_path = os.path.join(
        continual_checkpoint_root, f"round_{completed_rounds:04d}"
    )
    checkpoint = {
        "joint_train_state": joint_state,
        "policy_train_state": policy_state,
        "input_mean": input_mean,
        "input_std": input_std,
        "residual_target_mean": target_mean,
        "residual_target_std": target_std,
        "next_dynamics_stage_prior_bank": fixed_prior_bank,
        "completed_rounds": jnp.asarray(completed_rounds),
        "global_dynamics_update": jnp.asarray(global_dynamics_update),
        "replay_num_groups": jnp.asarray(replay_buffer.num_groups),
    }
    checkpointer.save(checkpoint_path, checkpoint, force=True)
    return checkpoint_path

# %% [markdown]
# ## 11. Run the alternating continual-learning pipeline
#
# The ordering is intentional: Stage 1 uses the prior bank produced by the previous Stage 2; the first iteration uses an initial standard-normal bank. Stage 2 then samples the next bank while optimizing the policy. Simulated policy-improvement trajectories are not inserted into the deployment replay buffer.
#
# Collection failure is nonfatal. Valid prefixes of terminated deployment rollouts contribute masked dynamics groups. If a round adds no group, Stage 1 trains from accumulated replay; if replay is still empty, only Stage 1 is skipped. Stage 2 always runs. During differentiable policy rollouts, the terminal transition and its penalty contribute to the objective, while rewards and state evolution after collision are masked.
#
# For a short compilation/smoke test, temporarily set `num_continual_rounds=1`, `dynamics_updates_per_round=1`, `policy_num_envs` to a small value, and `policy_rollout_horizon` before running the configuration-dependent cells.

# %%
input_mean = startup_input_mean
input_std = startup_input_std
residual_target_mean = startup_residual_target_mean
residual_target_std = startup_residual_target_std

# The only prior sample created outside Stage 2: it is required by the first
# Stage 1 before any policy-improvement rollout has occurred.
fixed_prior_bank = jax.random.normal(
    experiment_key(100), (policy_num_envs, latent_dim)
)
global_dynamics_update = pretrained_vnd_completed_updates
if (
    initialize_vnd_from_pretrained_checkpoint
    and not update_normalization_from_continual_buffer
):
    print(
        "Using the pretrained VND normalization statistics. New replay "
        "groups will not replace them."
    )

training_history = {
    "dynamics_total": [],
    "dynamics_loss": [],
    "reconstruction_loss": [],
    "mmd_loss": [],
    "mmd_weight": [],
    "dynamics_gradient_norm": [],
    "dynamics_update_norm": [],
    "policy_loss": [],
    "policy_return": [],
    "policy_reward": [],
    "policy_position_error": [],
    "policy_gradient_norm": [],
    "policy_update_norm": [],
    "policy_update_applied_fraction": [],
    "replay_groups": [],
    "round_duration": [],
}

pipeline_start = time.perf_counter()
for continual_round in range(num_continual_rounds):
    round_start = time.perf_counter()
    round_key = jax.random.fold_in(experiment_key(200), continual_round)
    key_collection_base, key_prior_base, key_dynamics, key_policy = jax.random.split(
        round_key, 4
    )

    # Stages 1A/1B: retain valid prefixes from successful and failed
    # rollouts. Retry only when no rollout supplies a context plus one
    # valid target; failure to collect is nonfatal for the round.
    longest_valid_rollout = 0
    for collection_attempt in range(max_collection_attempts_per_round):
        key_collection = jax.random.fold_in(
            key_collection_base, collection_attempt
        )
        key_prior = jax.random.fold_in(key_prior_base, collection_attempt)
        rollout_states, rollout_actions, rollout_done = (
            collect_deployment_rollouts(
                policy_train_state.params,
                joint_train_state.params,
                input_mean,
                input_std,
                key_collection,
            )
        )
        valid_transition = (
            jnp.cumsum(rollout_done, axis=1) - rollout_done
        ) == 0
        longest_valid_rollout = max(
            longest_valid_rollout,
            int(jax.device_get(valid_transition.sum(axis=1).max())),
        )
        (
            new_contexts, new_dynamics_inputs, new_targets,
            new_target_masks,
        ) = (
            build_groups_from_collection(
                rollout_states, rollout_actions, rollout_done, key_prior
            )
        )
        if new_contexts.shape[0] > 0:
            break
        print(
            f"Collection attempt {collection_attempt + 1}/"
            f"{max_collection_attempts_per_round} produced no valid "
            f"{context_length}-step context plus target; retrying."
        )
    else:
        print(
            f"No new replay group after "
            f"{max_collection_attempts_per_round} collection batches. "
            f"The longest valid prefix had {longest_valid_rollout} "
            "steps. Continuing the round without new dynamics data."
        )

    new_group_count = new_contexts.shape[0]
    new_valid_target_count = int(jax.device_get(new_target_masks.sum()))
    if new_group_count > 0:
        replay_buffer.append(
            new_contexts, new_dynamics_inputs, new_targets,
            new_target_masks,
        )
    if update_normalization_from_continual_buffer and replay_buffer.num_groups:
        (
            input_mean,
            input_std,
            residual_target_mean,
            residual_target_std,
        ) = replay_buffer.statistics()

    # Stage 1C: train from accumulated replay, even when this round did
    # not add data. If replay is empty, skip only Stage 1C.
    dynamics_stage_ran = replay_buffer.num_groups > 0
    if dynamics_stage_ran:
        joint_train_state, dynamics_metrics = run_dynamics_stage(
            joint_train_state,
            replay_buffer,
            fixed_prior_bank,
            input_mean,
            input_std,
            residual_target_mean,
            residual_target_std,
            global_dynamics_update,
            key_dynamics,
        )
        global_dynamics_update += dynamics_updates_per_round
    else:
        dynamics_metrics = None
        print("Replay is empty; skipping only the dynamics stage.")

    # Stage 2: freeze VND, sample fresh rollout latents, and update the policy.
    policy_train_state, policy_metrics, fixed_prior_bank = run_policy_stage(
        policy_train_state,
        joint_train_state.params,
        input_mean,
        input_std,
        residual_target_mean,
        residual_target_std,
        key_policy,
    )

    host_dynamics_metrics = None
    if dynamics_stage_ran:
        host_dynamics_metrics = np.asarray(jax.device_get(dynamics_metrics))
        training_history["dynamics_total"].extend(
            host_dynamics_metrics[:, 0]
        )
        training_history["dynamics_loss"].extend(
            host_dynamics_metrics[:, 1]
        )
        training_history["reconstruction_loss"].extend(
            host_dynamics_metrics[:, 2]
        )
        training_history["mmd_loss"].extend(
            host_dynamics_metrics[:, 3]
        )
        training_history["mmd_weight"].extend(
            host_dynamics_metrics[:, 4]
        )
        training_history["dynamics_gradient_norm"].extend(
            host_dynamics_metrics[:, 5]
        )
        training_history["dynamics_update_norm"].extend(
            host_dynamics_metrics[:, 6]
        )
    host_policy_metrics = np.asarray(jax.device_get(policy_metrics))
    training_history["policy_loss"].append(host_policy_metrics[:, 0].mean())
    training_history["policy_return"].append(host_policy_metrics[:, 1].mean())
    training_history["policy_reward"].append(
        host_policy_metrics[:, 2].mean()
    )
    training_history["policy_position_error"].append(
        host_policy_metrics[:, 3].mean()
    )
    training_history["policy_gradient_norm"].append(
        host_policy_metrics[:, 4].mean()
    )
    training_history["policy_update_norm"].append(
        host_policy_metrics[:, 5].mean()
    )
    policy_update_applied_fraction = host_policy_metrics[:, 6].mean()
    training_history["policy_update_applied_fraction"].append(
        policy_update_applied_fraction
    )
    training_history["replay_groups"].append(replay_buffer.num_groups)
    round_duration = time.perf_counter() - round_start
    training_history["round_duration"].append(round_duration)

    if wandb_run is not None:
        diagnostic_raw_contexts = None
        if new_group_count > 0:
            diagnostic_raw_contexts = new_contexts[:min(256, new_group_count)]
        elif replay_buffer.num_groups > 0:
            diagnostic_sample_size = min(256, replay_buffer.num_groups)
            diagnostic_raw_contexts = replay_buffer.sample(
                jax.random.fold_in(round_key, 99), diagnostic_sample_size
            )[0]
        host_diagnostic_latents = None
        if diagnostic_raw_contexts is not None:
            diagnostic_contexts = normalize_state_actions(
                diagnostic_raw_contexts, input_mean, input_std
            )
            diagnostic_latents = trajectory_encoder.apply(
                joint_train_state.params["encoder"], diagnostic_contexts
            )
            host_diagnostic_latents = np.asarray(
                jax.device_get(diagnostic_latents)
            )
        encoder_parameter_norm = float(jax.device_get(
            optax.global_norm(joint_train_state.params["encoder"])
        ))
        residual_parameter_norm = float(jax.device_get(
            optax.global_norm(joint_train_state.params["residual"])
        ))
        decoder_parameter_norm = float(jax.device_get(
            optax.global_norm(joint_train_state.params["decoder"])
        ))
        policy_parameter_norm = float(jax.device_get(
            optax.global_norm(policy_train_state.params)
        ))
        round_log = {
            "continual/round": continual_round + 1,
            "policy/loss": host_policy_metrics[:, 0].mean(),
            "policy/return": host_policy_metrics[:, 1].mean(),
            "policy/mean_reward": host_policy_metrics[:, 2].mean(),
            "policy/position_error_m": (
                host_policy_metrics[:, 3].mean()
            ),
            "policy/gradient_norm": host_policy_metrics[:, 4].mean(),
            "policy/update_norm": host_policy_metrics[:, 5].mean(),
            "policy/update_applied_fraction": (
                policy_update_applied_fraction
            ),
            "dynamics_round/skipped": int(not dynamics_stage_ran),
            "replay/groups": replay_buffer.num_groups,
            "replay/new_groups": new_group_count,
            "replay/new_valid_targets": new_valid_target_count,
            "collection/attempts": collection_attempt + 1,
            "collection/longest_valid_steps": longest_valid_rollout,
            "parameters/encoder_norm": encoder_parameter_norm,
            "parameters/residual_norm": residual_parameter_norm,
            "parameters/decoder_norm": decoder_parameter_norm,
            "parameters/policy_norm": policy_parameter_norm,
            "timing/round_seconds": round_duration,
        }
        if dynamics_stage_ran:
            round_log.update({
                "dynamics_round/final_total_loss": host_dynamics_metrics[-1, 0],
                "dynamics_round/final_L_dyn": host_dynamics_metrics[-1, 1],
                "dynamics_round/final_L_rec": host_dynamics_metrics[-1, 2],
                "dynamics_round/final_L_mmd": host_dynamics_metrics[-1, 3],
                "dynamics_round/mean_L_dyn": host_dynamics_metrics[:, 1].mean(),
                "dynamics_round/mean_L_mmd": host_dynamics_metrics[:, 3].mean(),
            })
        if host_diagnostic_latents is not None:
            round_log.update({
                "encoder/latent_mean": host_diagnostic_latents.mean(),
                "encoder/latent_std": host_diagnostic_latents.std(),
                "encoder/latent_abs_mean": np.abs(
                    host_diagnostic_latents
                ).mean(),
                "encoder/latent_max_abs": np.abs(
                    host_diagnostic_latents
                ).max(),
            })
            latent_dimension_means = host_diagnostic_latents.mean(axis=0)
            latent_dimension_stds = host_diagnostic_latents.std(axis=0)
            for latent_index in range(latent_dim):
                round_log[f"encoder/latent_mean_{latent_index:02d}"] = (
                    latent_dimension_means[latent_index]
                )
                round_log[f"encoder/latent_std_{latent_index:02d}"] = (
                    latent_dimension_stds[latent_index]
                )
            if (
                wandb_histogram_every_rounds
                and (continual_round + 1) % wandb_histogram_every_rounds == 0
            ):
                round_log["encoder/latent_histogram"] = wandb.Histogram(
                    host_diagnostic_latents
                )
        wandb_run.log(round_log)

    if checkpoint_every_rounds and (
        (continual_round + 1) % checkpoint_every_rounds == 0
        or continual_round + 1 == num_continual_rounds
    ):
        saved_path = save_continual_checkpoint(
            continual_round + 1,
            joint_train_state,
            policy_train_state,
            input_mean,
            input_std,
            residual_target_mean,
            residual_target_std,
            fixed_prior_bank,
            global_dynamics_update,
        )
    else:
        saved_path = None

    if dynamics_stage_ran:
        dynamics_status = (
            f"L_dyn {host_dynamics_metrics[-1, 1]:.4e} | "
            f"L_mmd {host_dynamics_metrics[-1, 3]:.4e} | "
            f"lambda_mmd {host_dynamics_metrics[-1, 4]:.2e}"
        )
    else:
        dynamics_status = "dynamics skipped (empty replay)"
    if policy_update_applied_fraction < 1.0:
        print(
            "WARNING: skipped a policy update because its loss, "
            "gradients, parameters, or optimizer state were non-finite."
        )
    print(
        f"Round {continual_round + 1:4d}/{num_continual_rounds} | "
        f"buffer {replay_buffer.num_groups:7d} groups | "
        f"new {new_group_count} groups/"
        f"{new_valid_target_count} targets | {dynamics_status} | "
        f"policy return {host_policy_metrics[:, 1].mean():.4f} | "
        f"mean reward {host_policy_metrics[:, 2].mean():.4f} | "
        f"position error {host_policy_metrics[:, 3].mean():.4f} m | "
        f"{training_history['round_duration'][-1]:.1f} s"
    )
    if saved_path is not None:
        print(f"  checkpoint: {saved_path}")

total_pipeline_seconds = time.perf_counter() - pipeline_start
print(
    f"Completed {num_continual_rounds} rounds in "
    f"{total_pipeline_seconds:.1f} s"
)
if wandb_run is not None:
    wandb_run.summary["completed_rounds"] = num_continual_rounds
    wandb_run.summary["total_pipeline_seconds"] = total_pipeline_seconds
    wandb_run.finish()
# Out:
# Using the pretrained VND normalization statistics. New replay groups will not replace them.
# Round    1/10000 | buffer     768 groups | new 768 groups/58880 targets | L_dyn 1.2376e-05 | L_mmd 3.7908e-02 | lambda_mmd 1.00e-05 | policy return -1.2174 | mean reward -0.0049 | position error 0.3812 m | 35.4 s
# Round    2/10000 | buffer    1536 groups | new 768 groups/58880 targets | L_dyn 5.3839e-06 | L_mmd 5.3137e-02 | lambda_mmd 1.00e-05 | policy return -1.1275 | mean reward -0.0045 | position error 0.3379 m | 11.0 s
# Round    3/10000 | buffer    2304 groups | new 768 groups/58880 targets | L_dyn 9.3897e-06 | L_mmd 3.8564e-02 | lambda_mmd 1.00e-05 | policy return -0.9939 | mean reward -0.0040 | position error 0.2669 m | 4.6 s
# Round    4/10000 | buffer    3072 groups | new 768 groups/58880 targets | L_dyn 1.2282e-05 | L_mmd 4.8788e-02 | lambda_mmd 1.00e-05 | policy return -0.9698 | mean reward -0.0039 | position error 0.2455 m | 4.6 s
# Round    5/10000 | buffer    3840 groups | new 768 groups/58880 targets | L_dyn 2.2879e-05 | L_mmd 4.4331e-02 | lambda_mmd 1.00e-05 | policy return -0.9270 | mean reward -0.0037 | position error 0.2350 m | 4.6 s
# Round    6/10000 | buffer    4608 groups | new 768 groups/58880 targets | L_dyn 1.9334e-05 | L_mmd 4.3771e-02 | lambda_mmd 1.00e-05 | policy return -0.8773 | mean reward -0.0035 | position error 0.2226 m | 4.8 s
# Round    7/10000 | buffer    5376 groups | new 768 groups/58880 targets | L_dyn 3.6130e-05 | L_mmd 4.1887e-02 | lambda_mmd 1.00e-05 | policy return -0.8843 | mean reward -0.0035 | position error 0.2301 m | 4.7 s
# Round    8/10000 | buffer    6144 groups | new 768 groups/58880 targets | L_dyn 3.8277e-05 | L_mmd 3.9147e-02 | lambda_mmd 1.00e-05 | policy return -0.8631 | mean reward -0.0035 | position error 0.2423 m | 4.8 s
# Round    9/10000 | buffer    6912 groups | new 768 groups/58880 targets | L_dyn 2.2872e-05 | L_mmd 4.8201e-02 | lambda_mmd 1.00e-05 | policy return -0.8413 | mean reward -0.0034 | position error 0.2559 m | 4.7 s
# Round   10/10000 | buffer    7680 groups | new 768 groups/58880 targets | L_dyn 3.3554e-05 | L_mmd 4.3567e-02 | lambda_mmd 1.00e-05 | policy return -0.8432 | mean reward -0.0034 | position error 0.2637 m | 4.8 s
# Round   11/10000 | buffer    8448 groups | new 768 groups/58880 targets | L_dyn 2.4882e-05 | L_mmd 4.9932e-02 | lambda_mmd 1.00e-05 | policy return -0.8534 | mean reward -0.0034 | position error 0.2625 m | 4.7 s
# Round   12/10000 | buffer    9216 groups | new 768 groups/58880 targets | L_dyn 4.7878e-05 | L_mmd 4.2603e-02 | lambda_mmd 1.00e-05 | policy return -0.8111 | mean reward -0.0032 | position error 0.2617 m | 4.9 s
# Round   13/10000 | buffer    9984 groups | new 768 groups/58880 targets | L_dyn 3.3363e-05 | L_mmd 5.3213e-02 | lambda_mmd 1.00e-05 | policy return -0.7994 | mean reward -0.0032 | position error 0.2596 m | 4.8 s
# Round   14/10000 | buffer   10752 groups | new 768 groups/58880 targets | L_dyn 2.5885e-05 | L_mmd 5.2516e-02 | lambda_mmd 1.00e-05 | policy return -0.8122 | mean reward -0.0032 | position error 0.2637 m | 4.9 s
# Round   15/10000 | buffer   11520 groups | new 768 groups/58880 targets | L_dyn 3.1964e-05 | L_mmd 4.5460e-02 | lambda_mmd 1.00e-05 | policy return -0.8256 | mean reward -0.0033 | position error 0.2628 m | 4.8 s
# Round   16/10000 | buffer   12288 groups | new 768 groups/58880 targets | L_dyn 4.0018e-05 | L_mmd 4.7665e-02 | lambda_mmd 1.00e-05 | policy return -0.8025 | mean reward -0.0032 | position error 0.2659 m | 5.0 s
# Round   17/10000 | buffer   13056 groups | new 768 groups/58880 targets | L_dyn 2.6444e-05 | L_mmd 4.8694e-02 | lambda_mmd 1.00e-05 | policy return -0.8066 | mean reward -0.0032 | position error 0.2654 m | 5.0 s
# Round   18/10000 | buffer   13824 groups | new 768 groups/58880 targets | L_dyn 1.7454e-05 | L_mmd 6.5021e-02 | lambda_mmd 1.00e-05 | policy return -0.8182 | mean reward -0.0033 | position error 0.2678 m | 4.8 s
# Round   19/10000 | buffer   14592 groups | new 768 groups/58880 targets | L_dyn 4.2243e-05 | L_mmd 5.3298e-02 | lambda_mmd 1.00e-05 | policy return -0.8249 | mean reward -0.0033 | position error 0.2668 m | 4.8 s
# Round   20/10000 | buffer   15360 groups | new 768 groups/58880 targets | L_dyn 2.3974e-05 | L_mmd 5.4900e-02 | lambda_mmd 1.00e-05 | policy return -0.8137 | mean reward -0.0033 | position error 0.2587 m | 4.9 s
# Round   21/10000 | buffer   16128 groups | new 768 groups/58880 targets | L_dyn 2.8841e-05 | L_mmd 5.8025e-02 | lambda_mmd 1.00e-05 | policy return -0.8011 | mean reward -0.0032 | position error 0.2467 m | 4.9 s
# Round   22/10000 | buffer   16896 groups | new 768 groups/58880 targets | L_dyn 3.2415e-05 | L_mmd 5.3061e-02 | lambda_mmd 1.00e-05 | policy return -0.7979 | mean reward -0.0032 | position error 0.2455 m | 5.1 s
# Round   23/10000 | buffer   17664 groups | new 768 groups/58880 targets | L_dyn 2.3251e-05 | L_mmd 5.1105e-02 | lambda_mmd 1.00e-05 | policy return -0.7697 | mean reward -0.0031 | position error 0.2380 m | 4.7 s
# Round   24/10000 | buffer   18432 groups | new 768 groups/58880 targets | L_dyn 2.6675e-05 | L_mmd 6.5066e-02 | lambda_mmd 1.00e-05 | policy return -0.8056 | mean reward -0.0032 | position error 0.2447 m | 4.8 s
# Round   25/10000 | buffer   19200 groups | new 768 groups/58880 targets | L_dyn 2.2555e-05 | L_mmd 5.2768e-02 | lambda_mmd 1.00e-05 | policy return -0.8251 | mean reward -0.0033 | position error 0.2463 m | 4.7 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0025
# Round   26/10000 | buffer   19968 groups | new 768 groups/58880 targets | L_dyn 2.4119e-05 | L_mmd 6.3103e-02 | lambda_mmd 1.00e-05 | policy return -0.7848 | mean reward -0.0031 | position error 0.2382 m | 4.8 s
# Round   27/10000 | buffer   20736 groups | new 768 groups/58880 targets | L_dyn 2.3843e-05 | L_mmd 5.6366e-02 | lambda_mmd 1.00e-05 | policy return -0.7763 | mean reward -0.0031 | position error 0.2345 m | 4.8 s
# Round   28/10000 | buffer   21504 groups | new 768 groups/58880 targets | L_dyn 2.0401e-05 | L_mmd 5.9688e-02 | lambda_mmd 1.00e-05 | policy return -0.7711 | mean reward -0.0031 | position error 0.2310 m | 4.7 s
# Round   29/10000 | buffer   22272 groups | new 768 groups/58880 targets | L_dyn 1.7717e-05 | L_mmd 6.4289e-02 | lambda_mmd 1.00e-05 | policy return -0.7654 | mean reward -0.0031 | position error 0.2298 m | 4.9 s
# Round   30/10000 | buffer   23040 groups | new 768 groups/58880 targets | L_dyn 2.1846e-05 | L_mmd 5.3797e-02 | lambda_mmd 1.00e-05 | policy return -0.7772 | mean reward -0.0031 | position error 0.2284 m | 4.9 s
# Round   31/10000 | buffer   23808 groups | new 768 groups/58880 targets | L_dyn 2.3121e-05 | L_mmd 4.4639e-02 | lambda_mmd 1.00e-05 | policy return -0.7955 | mean reward -0.0032 | position error 0.2358 m | 4.9 s
# Round   32/10000 | buffer   24576 groups | new 768 groups/58880 targets | L_dyn 1.9742e-05 | L_mmd 5.6504e-02 | lambda_mmd 1.00e-05 | policy return -0.7690 | mean reward -0.0031 | position error 0.2277 m | 4.8 s
# Round   33/10000 | buffer   25344 groups | new 768 groups/58880 targets | L_dyn 2.5616e-05 | L_mmd 5.5647e-02 | lambda_mmd 1.00e-05 | policy return -0.7835 | mean reward -0.0031 | position error 0.2305 m | 4.8 s
# Round   34/10000 | buffer   26112 groups | new 768 groups/58880 targets | L_dyn 1.7818e-05 | L_mmd 5.8618e-02 | lambda_mmd 1.00e-05 | policy return -0.7773 | mean reward -0.0031 | position error 0.2347 m | 4.8 s
# Round   35/10000 | buffer   26880 groups | new 768 groups/58880 targets | L_dyn 1.8695e-05 | L_mmd 5.5823e-02 | lambda_mmd 1.00e-05 | policy return -0.7723 | mean reward -0.0031 | position error 0.2326 m | 4.9 s
# Round   36/10000 | buffer   27648 groups | new 768 groups/58880 targets | L_dyn 1.7944e-05 | L_mmd 6.8657e-02 | lambda_mmd 1.00e-05 | policy return -0.7803 | mean reward -0.0031 | position error 0.2367 m | 4.9 s
# Round   37/10000 | buffer   28416 groups | new 768 groups/58880 targets | L_dyn 2.9353e-05 | L_mmd 5.4923e-02 | lambda_mmd 1.00e-05 | policy return -0.7599 | mean reward -0.0030 | position error 0.2324 m | 4.9 s
# Round   38/10000 | buffer   29184 groups | new 768 groups/58880 targets | L_dyn 2.6271e-05 | L_mmd 4.9615e-02 | lambda_mmd 1.00e-05 | policy return -0.7516 | mean reward -0.0030 | position error 0.2250 m | 5.1 s
# Round   39/10000 | buffer   29952 groups | new 768 groups/58880 targets | L_dyn 2.4189e-05 | L_mmd 6.3275e-02 | lambda_mmd 1.00e-05 | policy return -0.7779 | mean reward -0.0031 | position error 0.2308 m | 5.0 s
# Round   40/10000 | buffer   30720 groups | new 768 groups/58880 targets | L_dyn 2.4442e-05 | L_mmd 5.8125e-02 | lambda_mmd 1.00e-05 | policy return -0.7516 | mean reward -0.0030 | position error 0.2263 m | 4.8 s
# Round   41/10000 | buffer   31488 groups | new 768 groups/58880 targets | L_dyn 2.0561e-05 | L_mmd 4.8766e-02 | lambda_mmd 1.00e-05 | policy return -0.7737 | mean reward -0.0031 | position error 0.2268 m | 4.9 s
# Round   42/10000 | buffer   32256 groups | new 768 groups/58880 targets | L_dyn 1.2743e-05 | L_mmd 5.3169e-02 | lambda_mmd 1.00e-05 | policy return -0.7738 | mean reward -0.0031 | position error 0.2285 m | 4.8 s
# Round   43/10000 | buffer   33024 groups | new 768 groups/58880 targets | L_dyn 2.7794e-05 | L_mmd 5.7562e-02 | lambda_mmd 1.00e-05 | policy return -0.7490 | mean reward -0.0030 | position error 0.2223 m | 4.8 s
# Round   44/10000 | buffer   33792 groups | new 768 groups/58880 targets | L_dyn 1.7335e-05 | L_mmd 5.3258e-02 | lambda_mmd 1.00e-05 | policy return -0.7869 | mean reward -0.0031 | position error 0.2329 m | 4.8 s
# Round   45/10000 | buffer   34560 groups | new 768 groups/58880 targets | L_dyn 1.8315e-05 | L_mmd 5.3804e-02 | lambda_mmd 1.00e-05 | policy return -0.7499 | mean reward -0.0030 | position error 0.2209 m | 4.8 s
# Round   46/10000 | buffer   35328 groups | new 768 groups/58880 targets | L_dyn 1.6873e-05 | L_mmd 5.6984e-02 | lambda_mmd 1.00e-05 | policy return -0.7596 | mean reward -0.0030 | position error 0.2261 m | 4.8 s
# Round   47/10000 | buffer   36096 groups | new 768 groups/58880 targets | L_dyn 1.3236e-05 | L_mmd 6.0390e-02 | lambda_mmd 1.00e-05 | policy return -0.7755 | mean reward -0.0031 | position error 0.2284 m | 5.0 s
# Round   48/10000 | buffer   36864 groups | new 768 groups/58880 targets | L_dyn 2.5509e-05 | L_mmd 5.3237e-02 | lambda_mmd 1.00e-05 | policy return -0.7543 | mean reward -0.0030 | position error 0.2249 m | 4.9 s
# Round   49/10000 | buffer   37632 groups | new 768 groups/58880 targets | L_dyn 1.1664e-05 | L_mmd 6.5178e-02 | lambda_mmd 1.00e-05 | policy return -0.7575 | mean reward -0.0030 | position error 0.2283 m | 5.0 s
# Round   50/10000 | buffer   38400 groups | new 768 groups/58880 targets | L_dyn 1.3502e-05 | L_mmd 5.2510e-02 | lambda_mmd 1.00e-05 | policy return -0.7586 | mean reward -0.0030 | position error 0.2281 m | 5.0 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0050
# Round   51/10000 | buffer   39168 groups | new 768 groups/58880 targets | L_dyn 1.0406e-05 | L_mmd 6.2426e-02 | lambda_mmd 1.00e-05 | policy return -0.7658 | mean reward -0.0031 | position error 0.2263 m | 5.0 s
# Round   52/10000 | buffer   39936 groups | new 768 groups/58880 targets | L_dyn 2.9337e-05 | L_mmd 5.7868e-02 | lambda_mmd 1.00e-05 | policy return -0.7588 | mean reward -0.0030 | position error 0.2269 m | 4.9 s
# Round   53/10000 | buffer   40704 groups | new 768 groups/58880 targets | L_dyn 2.5106e-05 | L_mmd 5.5765e-02 | lambda_mmd 1.00e-05 | policy return -0.7713 | mean reward -0.0031 | position error 0.2288 m | 4.9 s
# Round   54/10000 | buffer   41472 groups | new 768 groups/58880 targets | L_dyn 2.2473e-05 | L_mmd 5.9962e-02 | lambda_mmd 1.00e-05 | policy return -0.7453 | mean reward -0.0030 | position error 0.2258 m | 4.7 s
# Round   55/10000 | buffer   42240 groups | new 768 groups/58880 targets | L_dyn 2.5586e-05 | L_mmd 6.1656e-02 | lambda_mmd 1.00e-05 | policy return -0.7796 | mean reward -0.0031 | position error 0.2298 m | 4.8 s
# Round   56/10000 | buffer   43008 groups | new 768 groups/58880 targets | L_dyn 1.4816e-05 | L_mmd 6.3337e-02 | lambda_mmd 1.00e-05 | policy return -0.7756 | mean reward -0.0031 | position error 0.2314 m | 4.8 s
# Round   57/10000 | buffer   43776 groups | new 768 groups/58880 targets | L_dyn 1.7311e-05 | L_mmd 5.5456e-02 | lambda_mmd 1.00e-05 | policy return -0.7459 | mean reward -0.0030 | position error 0.2234 m | 4.9 s
# Round   58/10000 | buffer   44544 groups | new 768 groups/58880 targets | L_dyn 1.2718e-05 | L_mmd 6.9369e-02 | lambda_mmd 1.00e-05 | policy return -0.7556 | mean reward -0.0030 | position error 0.2263 m | 5.0 s
# Round   59/10000 | buffer   45312 groups | new 768 groups/58880 targets | L_dyn 1.5473e-05 | L_mmd 6.8997e-02 | lambda_mmd 1.00e-05 | policy return -0.7636 | mean reward -0.0031 | position error 0.2275 m | 5.0 s
# Round   60/10000 | buffer   46080 groups | new 768 groups/58880 targets | L_dyn 1.4084e-05 | L_mmd 5.7705e-02 | lambda_mmd 1.00e-05 | policy return -0.7832 | mean reward -0.0031 | position error 0.2313 m | 4.8 s
# Round   61/10000 | buffer   46848 groups | new 768 groups/58880 targets | L_dyn 2.0421e-05 | L_mmd 4.9659e-02 | lambda_mmd 1.00e-05 | policy return -0.7621 | mean reward -0.0030 | position error 0.2281 m | 5.1 s
# Round   62/10000 | buffer   47616 groups | new 768 groups/58880 targets | L_dyn 1.7484e-05 | L_mmd 6.4723e-02 | lambda_mmd 1.00e-05 | policy return -0.7725 | mean reward -0.0031 | position error 0.2336 m | 4.9 s
# Round   63/10000 | buffer   48384 groups | new 768 groups/58880 targets | L_dyn 2.1458e-05 | L_mmd 5.9391e-02 | lambda_mmd 1.00e-05 | policy return -0.7656 | mean reward -0.0031 | position error 0.2334 m | 4.9 s
# Round   64/10000 | buffer   49152 groups | new 768 groups/58880 targets | L_dyn 1.5565e-05 | L_mmd 5.7936e-02 | lambda_mmd 1.00e-05 | policy return -0.7564 | mean reward -0.0030 | position error 0.2304 m | 4.9 s
# Round   65/10000 | buffer   49920 groups | new 768 groups/58880 targets | L_dyn 1.8466e-05 | L_mmd 5.5417e-02 | lambda_mmd 1.00e-05 | policy return -0.7606 | mean reward -0.0030 | position error 0.2292 m | 5.1 s
# Round   66/10000 | buffer   50688 groups | new 768 groups/58880 targets | L_dyn 9.3361e-06 | L_mmd 6.6702e-02 | lambda_mmd 1.00e-05 | policy return -0.7741 | mean reward -0.0031 | position error 0.2320 m | 4.8 s
# Round   67/10000 | buffer   51456 groups | new 768 groups/58880 targets | L_dyn 1.5290e-05 | L_mmd 6.6420e-02 | lambda_mmd 1.00e-05 | policy return -0.7287 | mean reward -0.0029 | position error 0.2185 m | 5.2 s
# Round   68/10000 | buffer   52224 groups | new 768 groups/58880 targets | L_dyn 1.1183e-05 | L_mmd 5.6864e-02 | lambda_mmd 1.00e-05 | policy return -0.7694 | mean reward -0.0031 | position error 0.2282 m | 4.8 s
# Round   69/10000 | buffer   52992 groups | new 768 groups/58880 targets | L_dyn 1.3354e-05 | L_mmd 6.0540e-02 | lambda_mmd 1.00e-05 | policy return -0.7691 | mean reward -0.0031 | position error 0.2290 m | 4.9 s
# Round   70/10000 | buffer   53760 groups | new 768 groups/58880 targets | L_dyn 2.2399e-05 | L_mmd 6.0542e-02 | lambda_mmd 1.00e-05 | policy return -0.7605 | mean reward -0.0030 | position error 0.2273 m | 4.8 s
# Round   71/10000 | buffer   54528 groups | new 768 groups/58880 targets | L_dyn 1.8046e-05 | L_mmd 6.2779e-02 | lambda_mmd 1.00e-05 | policy return -0.7512 | mean reward -0.0030 | position error 0.2241 m | 4.9 s
# Round   72/10000 | buffer   55296 groups | new 768 groups/58880 targets | L_dyn 2.2042e-05 | L_mmd 5.7373e-02 | lambda_mmd 1.00e-05 | policy return -0.7437 | mean reward -0.0030 | position error 0.2218 m | 4.8 s
# Round   73/10000 | buffer   56064 groups | new 768 groups/58880 targets | L_dyn 2.1529e-05 | L_mmd 6.3084e-02 | lambda_mmd 1.00e-05 | policy return -0.7775 | mean reward -0.0031 | position error 0.2309 m | 5.0 s
# Round   74/10000 | buffer   56832 groups | new 768 groups/58880 targets | L_dyn 1.2085e-05 | L_mmd 6.1086e-02 | lambda_mmd 1.00e-05 | policy return -0.7468 | mean reward -0.0030 | position error 0.2242 m | 5.0 s
# Round   75/10000 | buffer   57600 groups | new 768 groups/58880 targets | L_dyn 1.5520e-05 | L_mmd 6.5917e-02 | lambda_mmd 1.00e-05 | policy return -0.7672 | mean reward -0.0031 | position error 0.2267 m | 4.9 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0075
# Round   76/10000 | buffer   58368 groups | new 768 groups/58880 targets | L_dyn 1.4630e-05 | L_mmd 5.9679e-02 | lambda_mmd 1.00e-05 | policy return -0.7711 | mean reward -0.0031 | position error 0.2304 m | 5.2 s
# Round   77/10000 | buffer   59136 groups | new 768 groups/58880 targets | L_dyn 1.3008e-05 | L_mmd 5.9724e-02 | lambda_mmd 1.00e-05 | policy return -0.7449 | mean reward -0.0030 | position error 0.2231 m | 5.2 s
# Round   78/10000 | buffer   59904 groups | new 768 groups/58880 targets | L_dyn 1.8507e-05 | L_mmd 6.1950e-02 | lambda_mmd 1.00e-05 | policy return -0.7526 | mean reward -0.0030 | position error 0.2244 m | 4.9 s
# Round   79/10000 | buffer   60672 groups | new 768 groups/58880 targets | L_dyn 1.4222e-05 | L_mmd 5.7527e-02 | lambda_mmd 1.00e-05 | policy return -0.7480 | mean reward -0.0030 | position error 0.2236 m | 5.0 s
# Round   80/10000 | buffer   61440 groups | new 768 groups/58880 targets | L_dyn 1.5059e-05 | L_mmd 5.3683e-02 | lambda_mmd 1.00e-05 | policy return -0.7468 | mean reward -0.0030 | position error 0.2218 m | 4.9 s
# Round   81/10000 | buffer   62208 groups | new 768 groups/58880 targets | L_dyn 9.1538e-06 | L_mmd 6.3042e-02 | lambda_mmd 1.00e-05 | policy return -0.7819 | mean reward -0.0031 | position error 0.2311 m | 4.9 s
# Round   82/10000 | buffer   62976 groups | new 768 groups/58880 targets | L_dyn 1.8584e-05 | L_mmd 5.8186e-02 | lambda_mmd 1.00e-05 | policy return -0.7461 | mean reward -0.0030 | position error 0.2241 m | 4.9 s
# Round   83/10000 | buffer   63744 groups | new 768 groups/58880 targets | L_dyn 1.1092e-05 | L_mmd 6.3723e-02 | lambda_mmd 1.00e-05 | policy return -0.7351 | mean reward -0.0029 | position error 0.2213 m | 4.9 s
# Round   84/10000 | buffer   64512 groups | new 768 groups/58880 targets | L_dyn 2.0307e-05 | L_mmd 6.3035e-02 | lambda_mmd 1.00e-05 | policy return -0.7420 | mean reward -0.0030 | position error 0.2233 m | 4.9 s
# Round   85/10000 | buffer   65280 groups | new 768 groups/58880 targets | L_dyn 1.0330e-05 | L_mmd 5.6368e-02 | lambda_mmd 1.00e-05 | policy return -0.7623 | mean reward -0.0030 | position error 0.2255 m | 4.9 s
# Round   86/10000 | buffer   66048 groups | new 768 groups/58880 targets | L_dyn 1.1100e-05 | L_mmd 5.9513e-02 | lambda_mmd 1.00e-05 | policy return -0.7668 | mean reward -0.0031 | position error 0.2258 m | 5.1 s
# Round   87/10000 | buffer   66816 groups | new 768 groups/58880 targets | L_dyn 1.3328e-05 | L_mmd 5.9622e-02 | lambda_mmd 1.00e-05 | policy return -0.7888 | mean reward -0.0032 | position error 0.2307 m | 5.0 s
# Round   88/10000 | buffer   67584 groups | new 768 groups/58880 targets | L_dyn 1.2194e-05 | L_mmd 5.5726e-02 | lambda_mmd 1.00e-05 | policy return -0.7733 | mean reward -0.0031 | position error 0.2273 m | 5.2 s
# Round   89/10000 | buffer   68352 groups | new 768 groups/58880 targets | L_dyn 2.1482e-05 | L_mmd 5.7131e-02 | lambda_mmd 1.00e-05 | policy return -0.7537 | mean reward -0.0030 | position error 0.2231 m | 5.0 s
# Round   90/10000 | buffer   69120 groups | new 768 groups/58880 targets | L_dyn 1.1179e-05 | L_mmd 5.2922e-02 | lambda_mmd 1.00e-05 | policy return -0.7493 | mean reward -0.0030 | position error 0.2266 m | 5.0 s
# Round   91/10000 | buffer   69888 groups | new 768 groups/58880 targets | L_dyn 8.6904e-06 | L_mmd 6.3270e-02 | lambda_mmd 1.00e-05 | policy return -0.7445 | mean reward -0.0030 | position error 0.2301 m | 5.1 s
# Round   92/10000 | buffer   70656 groups | new 768 groups/58880 targets | L_dyn 2.3095e-05 | L_mmd 6.5527e-02 | lambda_mmd 1.00e-05 | policy return -0.7509 | mean reward -0.0030 | position error 0.2422 m | 5.0 s
# Round   93/10000 | buffer   71424 groups | new 768 groups/58880 targets | L_dyn 1.4929e-05 | L_mmd 6.8799e-02 | lambda_mmd 1.00e-05 | policy return -0.7518 | mean reward -0.0030 | position error 0.2519 m | 5.2 s
# Round   94/10000 | buffer   72192 groups | new 768 groups/58880 targets | L_dyn 1.0911e-05 | L_mmd 6.4043e-02 | lambda_mmd 1.00e-05 | policy return -0.7472 | mean reward -0.0030 | position error 0.2432 m | 5.0 s
# Round   95/10000 | buffer   72960 groups | new 768 groups/58880 targets | L_dyn 1.0789e-05 | L_mmd 6.4299e-02 | lambda_mmd 1.00e-05 | policy return -0.7429 | mean reward -0.0030 | position error 0.2269 m | 4.9 s
# Round   96/10000 | buffer   73728 groups | new 768 groups/58880 targets | L_dyn 2.8536e-05 | L_mmd 6.3486e-02 | lambda_mmd 1.00e-05 | policy return -0.7724 | mean reward -0.0031 | position error 0.2473 m | 5.0 s
# Round   97/10000 | buffer   74496 groups | new 768 groups/58880 targets | L_dyn 1.2263e-05 | L_mmd 6.0916e-02 | lambda_mmd 1.00e-05 | policy return -0.7654 | mean reward -0.0031 | position error 0.2359 m | 5.0 s
# Round   98/10000 | buffer   75264 groups | new 768 groups/58880 targets | L_dyn 1.0522e-05 | L_mmd 6.9261e-02 | lambda_mmd 1.00e-05 | policy return -0.7566 | mean reward -0.0030 | position error 0.2303 m | 5.0 s
# Round   99/10000 | buffer   76032 groups | new 768 groups/58880 targets | L_dyn 9.2365e-06 | L_mmd 5.5324e-02 | lambda_mmd 1.00e-05 | policy return -0.7681 | mean reward -0.0031 | position error 0.2422 m | 5.0 s
# Round  100/10000 | buffer   76800 groups | new 768 groups/58880 targets | L_dyn 2.0507e-05 | L_mmd 5.5711e-02 | lambda_mmd 1.00e-05 | policy return -0.7525 | mean reward -0.0030 | position error 0.2251 m | 4.6 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0100
# Round  101/10000 | buffer   77568 groups | new 768 groups/58880 targets | L_dyn 1.0229e-05 | L_mmd 6.7973e-02 | lambda_mmd 1.00e-05 | policy return -0.7731 | mean reward -0.0031 | position error 0.2380 m | 4.6 s
# Round  102/10000 | buffer   78336 groups | new 768 groups/58880 targets | L_dyn 1.3176e-05 | L_mmd 6.4658e-02 | lambda_mmd 1.00e-05 | policy return -0.7596 | mean reward -0.0030 | position error 0.2316 m | 4.6 s
# Round  103/10000 | buffer   79104 groups | new 768 groups/58880 targets | L_dyn 1.4188e-05 | L_mmd 5.8159e-02 | lambda_mmd 1.00e-05 | policy return -0.7510 | mean reward -0.0030 | position error 0.2310 m | 4.6 s
# Round  104/10000 | buffer   79872 groups | new 768 groups/58880 targets | L_dyn 7.9338e-06 | L_mmd 5.6310e-02 | lambda_mmd 1.00e-05 | policy return -0.7644 | mean reward -0.0031 | position error 0.2317 m | 4.6 s
# Round  105/10000 | buffer   80640 groups | new 768 groups/58880 targets | L_dyn 7.7557e-06 | L_mmd 5.5922e-02 | lambda_mmd 1.00e-05 | policy return -0.7439 | mean reward -0.0030 | position error 0.2249 m | 4.6 s
# Round  106/10000 | buffer   81408 groups | new 768 groups/58880 targets | L_dyn 1.4223e-05 | L_mmd 6.8321e-02 | lambda_mmd 1.00e-05 | policy return -0.7445 | mean reward -0.0030 | position error 0.2311 m | 4.6 s
# Round  107/10000 | buffer   82176 groups | new 768 groups/58880 targets | L_dyn 9.2373e-06 | L_mmd 5.9017e-02 | lambda_mmd 1.00e-05 | policy return -0.7463 | mean reward -0.0030 | position error 0.2248 m | 4.7 s
# Round  108/10000 | buffer   82944 groups | new 768 groups/58880 targets | L_dyn 1.2670e-05 | L_mmd 5.5839e-02 | lambda_mmd 1.00e-05 | policy return -0.7753 | mean reward -0.0031 | position error 0.2359 m | 4.6 s
# Round  109/10000 | buffer   83712 groups | new 768 groups/58880 targets | L_dyn 9.0105e-06 | L_mmd 5.8480e-02 | lambda_mmd 1.00e-05 | policy return -0.7476 | mean reward -0.0030 | position error 0.2251 m | 4.6 s
# Round  110/10000 | buffer   84480 groups | new 768 groups/58880 targets | L_dyn 1.4554e-05 | L_mmd 5.9492e-02 | lambda_mmd 1.00e-05 | policy return -0.7220 | mean reward -0.0029 | position error 0.2228 m | 4.6 s
# Round  111/10000 | buffer   85248 groups | new 768 groups/58880 targets | L_dyn 1.8935e-05 | L_mmd 5.5348e-02 | lambda_mmd 1.00e-05 | policy return -0.7594 | mean reward -0.0030 | position error 0.2308 m | 4.6 s
# Round  112/10000 | buffer   86016 groups | new 768 groups/58880 targets | L_dyn 1.5076e-05 | L_mmd 6.9845e-02 | lambda_mmd 1.00e-05 | policy return -0.7283 | mean reward -0.0029 | position error 0.2203 m | 4.6 s
# Round  113/10000 | buffer   86784 groups | new 768 groups/58880 targets | L_dyn 1.1327e-05 | L_mmd 6.1769e-02 | lambda_mmd 1.00e-05 | policy return -0.7359 | mean reward -0.0029 | position error 0.2264 m | 4.6 s
# Round  114/10000 | buffer   87552 groups | new 768 groups/58880 targets | L_dyn 6.8373e-06 | L_mmd 5.7168e-02 | lambda_mmd 1.00e-05 | policy return -0.7433 | mean reward -0.0030 | position error 0.2230 m | 4.7 s
# Round  115/10000 | buffer   88320 groups | new 768 groups/58880 targets | L_dyn 1.1181e-05 | L_mmd 5.6554e-02 | lambda_mmd 1.00e-05 | policy return -0.7703 | mean reward -0.0031 | position error 0.2310 m | 4.6 s
# Round  116/10000 | buffer   89088 groups | new 768 groups/58880 targets | L_dyn 7.9460e-06 | L_mmd 5.5406e-02 | lambda_mmd 1.00e-05 | policy return -0.7345 | mean reward -0.0029 | position error 0.2241 m | 4.6 s
# Round  117/10000 | buffer   89856 groups | new 768 groups/58880 targets | L_dyn 1.3706e-05 | L_mmd 6.0027e-02 | lambda_mmd 1.00e-05 | policy return -0.7422 | mean reward -0.0030 | position error 0.2239 m | 4.6 s
# Round  118/10000 | buffer   90624 groups | new 768 groups/58880 targets | L_dyn 5.2682e-06 | L_mmd 6.6759e-02 | lambda_mmd 1.00e-05 | policy return -0.7566 | mean reward -0.0030 | position error 0.2278 m | 4.7 s
# Round  119/10000 | buffer   91392 groups | new 768 groups/58880 targets | L_dyn 1.1535e-05 | L_mmd 6.5032e-02 | lambda_mmd 1.00e-05 | policy return -0.7434 | mean reward -0.0030 | position error 0.2222 m | 4.6 s
# Round  120/10000 | buffer   92160 groups | new 768 groups/58880 targets | L_dyn 9.4479e-06 | L_mmd 7.0949e-02 | lambda_mmd 1.00e-05 | policy return -0.7446 | mean reward -0.0030 | position error 0.2241 m | 4.6 s
# Round  121/10000 | buffer   92928 groups | new 768 groups/58880 targets | L_dyn 8.6520e-06 | L_mmd 5.8395e-02 | lambda_mmd 1.00e-05 | policy return -0.7524 | mean reward -0.0030 | position error 0.2253 m | 4.6 s
# Round  122/10000 | buffer   93696 groups | new 768 groups/58880 targets | L_dyn 1.3765e-05 | L_mmd 7.1618e-02 | lambda_mmd 1.00e-05 | policy return -0.7549 | mean reward -0.0030 | position error 0.2262 m | 4.6 s
# Round  123/10000 | buffer   94464 groups | new 768 groups/58880 targets | L_dyn 9.4511e-06 | L_mmd 5.3185e-02 | lambda_mmd 1.00e-05 | policy return -0.7302 | mean reward -0.0029 | position error 0.2210 m | 4.6 s
# Round  124/10000 | buffer   95232 groups | new 768 groups/58880 targets | L_dyn 8.4963e-06 | L_mmd 5.8809e-02 | lambda_mmd 1.00e-05 | policy return -0.7447 | mean reward -0.0030 | position error 0.2262 m | 4.7 s
# Round  125/10000 | buffer   96000 groups | new 768 groups/58880 targets | L_dyn 6.6196e-06 | L_mmd 7.0094e-02 | lambda_mmd 1.00e-05 | policy return -0.7376 | mean reward -0.0030 | position error 0.2225 m | 4.6 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0125
# Round  126/10000 | buffer   96768 groups | new 768 groups/58880 targets | L_dyn 8.6998e-06 | L_mmd 6.1665e-02 | lambda_mmd 1.00e-05 | policy return -0.7561 | mean reward -0.0030 | position error 0.2238 m | 4.7 s
# Round  127/10000 | buffer   97536 groups | new 768 groups/58880 targets | L_dyn 9.1970e-06 | L_mmd 6.7351e-02 | lambda_mmd 1.00e-05 | policy return -0.7458 | mean reward -0.0030 | position error 0.2243 m | 4.6 s
# Round  128/10000 | buffer   98304 groups | new 768 groups/58880 targets | L_dyn 1.0045e-05 | L_mmd 6.7124e-02 | lambda_mmd 1.00e-05 | policy return -0.7072 | mean reward -0.0028 | position error 0.2175 m | 4.7 s
# Round  129/10000 | buffer   99072 groups | new 768 groups/58880 targets | L_dyn 1.3523e-05 | L_mmd 5.6140e-02 | lambda_mmd 1.00e-05 | policy return -0.7511 | mean reward -0.0030 | position error 0.2237 m | 4.6 s
# Round  130/10000 | buffer   99840 groups | new 768 groups/58880 targets | L_dyn 8.1891e-06 | L_mmd 6.0848e-02 | lambda_mmd 1.00e-05 | policy return -0.7335 | mean reward -0.0029 | position error 0.2209 m | 4.7 s
# Round  131/10000 | buffer  100608 groups | new 768 groups/58880 targets | L_dyn 8.8484e-06 | L_mmd 6.3719e-02 | lambda_mmd 1.00e-05 | policy return -0.7460 | mean reward -0.0030 | position error 0.2223 m | 4.6 s
# Round  132/10000 | buffer  101376 groups | new 768 groups/58880 targets | L_dyn 8.1869e-06 | L_mmd 5.6852e-02 | lambda_mmd 1.00e-05 | policy return -0.7588 | mean reward -0.0030 | position error 0.2239 m | 4.7 s
# Round  133/10000 | buffer  102144 groups | new 768 groups/58880 targets | L_dyn 1.3242e-05 | L_mmd 5.8413e-02 | lambda_mmd 1.00e-05 | policy return -0.7424 | mean reward -0.0030 | position error 0.2216 m | 4.6 s
# Round  134/10000 | buffer  102912 groups | new 768 groups/58880 targets | L_dyn 1.0584e-05 | L_mmd 6.3951e-02 | lambda_mmd 1.00e-05 | policy return -0.7291 | mean reward -0.0029 | position error 0.2190 m | 4.7 s
# Round  135/10000 | buffer  103680 groups | new 768 groups/58880 targets | L_dyn 8.7730e-06 | L_mmd 6.6095e-02 | lambda_mmd 1.00e-05 | policy return -0.7338 | mean reward -0.0029 | position error 0.2226 m | 4.6 s
# Round  136/10000 | buffer  104448 groups | new 768 groups/58880 targets | L_dyn 1.3237e-05 | L_mmd 6.0334e-02 | lambda_mmd 1.00e-05 | policy return -0.7461 | mean reward -0.0030 | position error 0.2236 m | 4.6 s
# Round  137/10000 | buffer  105216 groups | new 768 groups/58880 targets | L_dyn 8.2480e-06 | L_mmd 6.2875e-02 | lambda_mmd 1.00e-05 | policy return -0.7474 | mean reward -0.0030 | position error 0.2223 m | 4.6 s
# Round  138/10000 | buffer  105984 groups | new 768 groups/58880 targets | L_dyn 7.3384e-06 | L_mmd 6.9200e-02 | lambda_mmd 1.00e-05 | policy return -0.7335 | mean reward -0.0029 | position error 0.2227 m | 4.6 s
# Round  139/10000 | buffer  106752 groups | new 768 groups/58880 targets | L_dyn 6.7039e-06 | L_mmd 6.3097e-02 | lambda_mmd 1.00e-05 | policy return -0.7405 | mean reward -0.0030 | position error 0.2226 m | 4.6 s
# Round  140/10000 | buffer  107520 groups | new 768 groups/58880 targets | L_dyn 7.9726e-06 | L_mmd 6.6114e-02 | lambda_mmd 1.00e-05 | policy return -0.7406 | mean reward -0.0030 | position error 0.2209 m | 4.6 s
# Round  141/10000 | buffer  108288 groups | new 768 groups/58880 targets | L_dyn 5.5030e-06 | L_mmd 6.5048e-02 | lambda_mmd 1.00e-05 | policy return -0.7468 | mean reward -0.0030 | position error 0.2235 m | 4.6 s
# Round  142/10000 | buffer  109056 groups | new 768 groups/58880 targets | L_dyn 1.1867e-05 | L_mmd 5.9938e-02 | lambda_mmd 1.00e-05 | policy return -0.7353 | mean reward -0.0029 | position error 0.2197 m | 4.6 s
# Round  143/10000 | buffer  109824 groups | new 768 groups/58880 targets | L_dyn 1.0945e-05 | L_mmd 5.9979e-02 | lambda_mmd 1.00e-05 | policy return -0.7388 | mean reward -0.0030 | position error 0.2210 m | 4.6 s
# Round  144/10000 | buffer  110592 groups | new 768 groups/58880 targets | L_dyn 7.0278e-06 | L_mmd 5.8518e-02 | lambda_mmd 1.00e-05 | policy return -0.7507 | mean reward -0.0030 | position error 0.2245 m | 4.6 s
# Round  145/10000 | buffer  111360 groups | new 768 groups/58880 targets | L_dyn 1.6235e-05 | L_mmd 6.4424e-02 | lambda_mmd 1.00e-05 | policy return -0.7506 | mean reward -0.0030 | position error 0.2253 m | 4.6 s
# Round  146/10000 | buffer  112128 groups | new 768 groups/58880 targets | L_dyn 8.3654e-06 | L_mmd 5.5688e-02 | lambda_mmd 1.00e-05 | policy return -0.7610 | mean reward -0.0030 | position error 0.2253 m | 4.6 s
# Round  147/10000 | buffer  112896 groups | new 768 groups/58880 targets | L_dyn 9.4146e-06 | L_mmd 6.1462e-02 | lambda_mmd 1.00e-05 | policy return -0.7220 | mean reward -0.0029 | position error 0.2208 m | 4.6 s
# Round  148/10000 | buffer  113664 groups | new 768 groups/58880 targets | L_dyn 1.3670e-05 | L_mmd 6.5128e-02 | lambda_mmd 1.00e-05 | policy return -0.7326 | mean reward -0.0029 | position error 0.2210 m | 4.6 s
# Round  149/10000 | buffer  114432 groups | new 768 groups/58880 targets | L_dyn 8.1563e-06 | L_mmd 6.9534e-02 | lambda_mmd 1.00e-05 | policy return -0.7467 | mean reward -0.0030 | position error 0.2225 m | 4.6 s
# Round  150/10000 | buffer  115200 groups | new 768 groups/58880 targets | L_dyn 9.4060e-06 | L_mmd 5.9776e-02 | lambda_mmd 1.00e-05 | policy return -0.7463 | mean reward -0.0030 | position error 0.2233 m | 4.6 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0150
# Round  151/10000 | buffer  115968 groups | new 768 groups/58880 targets | L_dyn 5.7315e-06 | L_mmd 6.6517e-02 | lambda_mmd 1.00e-05 | policy return -0.7025 | mean reward -0.0028 | position error 0.2161 m | 4.7 s
# Round  152/10000 | buffer  116736 groups | new 768 groups/58880 targets | L_dyn 5.4371e-06 | L_mmd 6.6361e-02 | lambda_mmd 1.00e-05 | policy return -0.7415 | mean reward -0.0030 | position error 0.2224 m | 4.6 s
# Round  153/10000 | buffer  117504 groups | new 768 groups/58880 targets | L_dyn 1.0305e-05 | L_mmd 5.8641e-02 | lambda_mmd 1.00e-05 | policy return -0.7252 | mean reward -0.0029 | position error 0.2185 m | 4.6 s
# Round  154/10000 | buffer  118272 groups | new 768 groups/58880 targets | L_dyn 9.7022e-06 | L_mmd 5.7039e-02 | lambda_mmd 1.00e-05 | policy return -0.7469 | mean reward -0.0030 | position error 0.2221 m | 4.6 s
# Round  155/10000 | buffer  119040 groups | new 768 groups/58880 targets | L_dyn 7.1877e-06 | L_mmd 6.7734e-02 | lambda_mmd 1.00e-05 | policy return -0.7281 | mean reward -0.0029 | position error 0.2201 m | 4.7 s
# Round  156/10000 | buffer  119808 groups | new 768 groups/58880 targets | L_dyn 1.0761e-05 | L_mmd 6.5067e-02 | lambda_mmd 1.00e-05 | policy return -0.7717 | mean reward -0.0031 | position error 0.2283 m | 4.6 s
# Round  157/10000 | buffer  120576 groups | new 768 groups/58880 targets | L_dyn 7.0046e-06 | L_mmd 6.2679e-02 | lambda_mmd 1.00e-05 | policy return -0.7220 | mean reward -0.0029 | position error 0.2185 m | 4.7 s
# Round  158/10000 | buffer  121344 groups | new 768 groups/58880 targets | L_dyn 8.1080e-06 | L_mmd 6.3708e-02 | lambda_mmd 1.00e-05 | policy return -0.7468 | mean reward -0.0030 | position error 0.2251 m | 4.6 s
# Round  159/10000 | buffer  122112 groups | new 768 groups/58880 targets | L_dyn 6.1849e-06 | L_mmd 6.6201e-02 | lambda_mmd 1.00e-05 | policy return -0.7404 | mean reward -0.0030 | position error 0.2199 m | 4.6 s
# Round  160/10000 | buffer  122880 groups | new 768 groups/58880 targets | L_dyn 6.8107e-06 | L_mmd 6.1860e-02 | lambda_mmd 1.00e-05 | policy return -0.7364 | mean reward -0.0029 | position error 0.2227 m | 4.6 s
# Round  161/10000 | buffer  123648 groups | new 768 groups/58880 targets | L_dyn 1.2195e-05 | L_mmd 6.2258e-02 | lambda_mmd 1.00e-05 | policy return -0.7620 | mean reward -0.0030 | position error 0.2267 m | 4.6 s
# Round  162/10000 | buffer  124416 groups | new 768 groups/58880 targets | L_dyn 7.3142e-06 | L_mmd 6.3227e-02 | lambda_mmd 1.00e-05 | policy return -0.7494 | mean reward -0.0030 | position error 0.2239 m | 4.6 s
# Round  163/10000 | buffer  125184 groups | new 768 groups/58880 targets | L_dyn 1.0110e-05 | L_mmd 6.0233e-02 | lambda_mmd 1.00e-05 | policy return -0.7345 | mean reward -0.0029 | position error 0.2210 m | 4.7 s
# Round  164/10000 | buffer  125952 groups | new 768 groups/58880 targets | L_dyn 7.6252e-06 | L_mmd 6.1705e-02 | lambda_mmd 1.00e-05 | policy return -0.7307 | mean reward -0.0029 | position error 0.2172 m | 4.6 s
# Round  165/10000 | buffer  126720 groups | new 768 groups/58880 targets | L_dyn 1.1390e-05 | L_mmd 6.9359e-02 | lambda_mmd 1.00e-05 | policy return -0.7349 | mean reward -0.0029 | position error 0.2210 m | 4.7 s
# Round  166/10000 | buffer  127488 groups | new 768 groups/58880 targets | L_dyn 1.1799e-05 | L_mmd 6.0160e-02 | lambda_mmd 1.00e-05 | policy return -0.7435 | mean reward -0.0030 | position error 0.2224 m | 4.6 s
# Round  167/10000 | buffer  128256 groups | new 768 groups/58880 targets | L_dyn 5.7537e-06 | L_mmd 5.8586e-02 | lambda_mmd 1.00e-05 | policy return -0.7267 | mean reward -0.0029 | position error 0.2179 m | 4.6 s
# Round  168/10000 | buffer  129024 groups | new 768 groups/58880 targets | L_dyn 9.6677e-06 | L_mmd 6.8120e-02 | lambda_mmd 1.00e-05 | policy return -0.7587 | mean reward -0.0030 | position error 0.2247 m | 4.6 s
# Round  169/10000 | buffer  129792 groups | new 768 groups/58880 targets | L_dyn 8.1951e-06 | L_mmd 6.0156e-02 | lambda_mmd 1.00e-05 | policy return -0.7511 | mean reward -0.0030 | position error 0.2254 m | 4.7 s
# Round  170/10000 | buffer  130560 groups | new 768 groups/58880 targets | L_dyn 1.0881e-05 | L_mmd 5.9916e-02 | lambda_mmd 1.00e-05 | policy return -0.7428 | mean reward -0.0030 | position error 0.2200 m | 4.6 s
# Round  171/10000 | buffer  131328 groups | new 768 groups/58880 targets | L_dyn 1.1330e-05 | L_mmd 5.7063e-02 | lambda_mmd 1.00e-05 | policy return -0.7337 | mean reward -0.0029 | position error 0.2214 m | 4.6 s
# Round  172/10000 | buffer  132096 groups | new 768 groups/58880 targets | L_dyn 6.1968e-06 | L_mmd 5.7426e-02 | lambda_mmd 1.00e-05 | policy return -0.7276 | mean reward -0.0029 | position error 0.2189 m | 4.6 s
# Round  173/10000 | buffer  132864 groups | new 768 groups/58880 targets | L_dyn 7.8610e-06 | L_mmd 5.7171e-02 | lambda_mmd 1.00e-05 | policy return -0.7580 | mean reward -0.0030 | position error 0.2233 m | 4.6 s
# Round  174/10000 | buffer  133632 groups | new 768 groups/58880 targets | L_dyn 8.1973e-06 | L_mmd 5.9858e-02 | lambda_mmd 1.00e-05 | policy return -0.7417 | mean reward -0.0030 | position error 0.2214 m | 4.6 s
# Round  175/10000 | buffer  134400 groups | new 768 groups/58880 targets | L_dyn 7.2450e-06 | L_mmd 6.5368e-02 | lambda_mmd 1.00e-05 | policy return -0.7288 | mean reward -0.0029 | position error 0.2225 m | 4.6 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0175
# Round  176/10000 | buffer  135168 groups | new 768 groups/58880 targets | L_dyn 1.0594e-05 | L_mmd 6.1446e-02 | lambda_mmd 1.00e-05 | policy return -0.7444 | mean reward -0.0030 | position error 0.2277 m | 4.6 s
# Round  177/10000 | buffer  135936 groups | new 768 groups/58880 targets | L_dyn 6.6434e-06 | L_mmd 6.6455e-02 | lambda_mmd 1.00e-05 | policy return -0.7327 | mean reward -0.0029 | position error 0.2267 m | 4.6 s
# Round  178/10000 | buffer  136704 groups | new 768 groups/58880 targets | L_dyn 4.8536e-06 | L_mmd 6.2341e-02 | lambda_mmd 1.00e-05 | policy return -0.7509 | mean reward -0.0030 | position error 0.2294 m | 4.6 s
# Round  179/10000 | buffer  137472 groups | new 768 groups/58880 targets | L_dyn 6.3623e-06 | L_mmd 6.6975e-02 | lambda_mmd 1.00e-05 | policy return -0.7416 | mean reward -0.0030 | position error 0.2264 m | 4.6 s
# Round  180/10000 | buffer  138240 groups | new 768 groups/58880 targets | L_dyn 6.9845e-06 | L_mmd 6.2656e-02 | lambda_mmd 1.00e-05 | policy return -0.7059 | mean reward -0.0028 | position error 0.2257 m | 4.6 s
# Round  181/10000 | buffer  139008 groups | new 768 groups/58880 targets | L_dyn 9.9907e-06 | L_mmd 5.2787e-02 | lambda_mmd 1.00e-05 | policy return -0.7581 | mean reward -0.0030 | position error 0.2350 m | 4.7 s
# Round  182/10000 | buffer  139776 groups | new 768 groups/58880 targets | L_dyn 1.0840e-05 | L_mmd 6.7516e-02 | lambda_mmd 1.00e-05 | policy return -0.7425 | mean reward -0.0030 | position error 0.2294 m | 4.6 s
# Round  183/10000 | buffer  140544 groups | new 768 groups/58880 targets | L_dyn 1.2083e-05 | L_mmd 6.0408e-02 | lambda_mmd 1.00e-05 | policy return -0.7442 | mean reward -0.0030 | position error 0.2238 m | 4.6 s
# Round  184/10000 | buffer  141312 groups | new 768 groups/58880 targets | L_dyn 8.8944e-06 | L_mmd 6.1949e-02 | lambda_mmd 1.00e-05 | policy return -0.7271 | mean reward -0.0029 | position error 0.2216 m | 4.7 s
# Round  185/10000 | buffer  142080 groups | new 768 groups/58880 targets | L_dyn 6.2187e-06 | L_mmd 6.2525e-02 | lambda_mmd 1.00e-05 | policy return -0.7201 | mean reward -0.0029 | position error 0.2233 m | 4.6 s
# Round  186/10000 | buffer  142848 groups | new 768 groups/58880 targets | L_dyn 1.3764e-05 | L_mmd 5.9646e-02 | lambda_mmd 1.00e-05 | policy return -0.7418 | mean reward -0.0030 | position error 0.2289 m | 4.7 s
# Round  187/10000 | buffer  143616 groups | new 768 groups/58880 targets | L_dyn 6.2907e-06 | L_mmd 6.2811e-02 | lambda_mmd 1.00e-05 | policy return -0.7424 | mean reward -0.0030 | position error 0.2261 m | 4.6 s
# Round  188/10000 | buffer  144384 groups | new 768 groups/58880 targets | L_dyn 6.7311e-06 | L_mmd 5.5395e-02 | lambda_mmd 1.00e-05 | policy return -0.7340 | mean reward -0.0029 | position error 0.2233 m | 4.6 s
# Round  189/10000 | buffer  145152 groups | new 768 groups/58880 targets | L_dyn 4.3553e-06 | L_mmd 6.8211e-02 | lambda_mmd 1.00e-05 | policy return -0.7236 | mean reward -0.0029 | position error 0.2220 m | 4.6 s
# Round  190/10000 | buffer  145920 groups | new 768 groups/58880 targets | L_dyn 1.4166e-05 | L_mmd 6.1679e-02 | lambda_mmd 1.00e-05 | policy return -0.7348 | mean reward -0.0029 | position error 0.2244 m | 4.7 s
# Round  191/10000 | buffer  146688 groups | new 768 groups/58880 targets | L_dyn 6.2994e-06 | L_mmd 6.5029e-02 | lambda_mmd 1.00e-05 | policy return -0.6988 | mean reward -0.0028 | position error 0.2151 m | 4.6 s
# Round  192/10000 | buffer  147456 groups | new 768 groups/58880 targets | L_dyn 6.8175e-06 | L_mmd 6.1970e-02 | lambda_mmd 1.00e-05 | policy return -0.7342 | mean reward -0.0029 | position error 0.2232 m | 4.7 s
# Round  193/10000 | buffer  148224 groups | new 768 groups/58880 targets | L_dyn 6.6605e-06 | L_mmd 7.2377e-02 | lambda_mmd 1.00e-05 | policy return -0.7359 | mean reward -0.0029 | position error 0.2267 m | 4.6 s
# Round  194/10000 | buffer  148992 groups | new 768 groups/58880 targets | L_dyn 9.5721e-06 | L_mmd 6.1315e-02 | lambda_mmd 1.00e-05 | policy return -0.7249 | mean reward -0.0029 | position error 0.2206 m | 4.7 s
# Round  195/10000 | buffer  149760 groups | new 768 groups/58880 targets | L_dyn 8.7484e-06 | L_mmd 5.9116e-02 | lambda_mmd 1.00e-05 | policy return -0.7483 | mean reward -0.0030 | position error 0.2274 m | 4.6 s
# Round  196/10000 | buffer  150528 groups | new 768 groups/58880 targets | L_dyn 4.8470e-06 | L_mmd 6.4210e-02 | lambda_mmd 1.00e-05 | policy return -0.7283 | mean reward -0.0029 | position error 0.2231 m | 4.6 s
# Round  197/10000 | buffer  151296 groups | new 768 groups/58880 targets | L_dyn 9.3717e-06 | L_mmd 6.0758e-02 | lambda_mmd 1.00e-05 | policy return -0.7251 | mean reward -0.0029 | position error 0.2193 m | 4.6 s
# Round  198/10000 | buffer  152064 groups | new 768 groups/58880 targets | L_dyn 6.7316e-06 | L_mmd 5.2005e-02 | lambda_mmd 1.00e-05 | policy return -0.7355 | mean reward -0.0029 | position error 0.2233 m | 4.7 s
# Round  199/10000 | buffer  152832 groups | new 768 groups/58880 targets | L_dyn 7.3909e-06 | L_mmd 6.0889e-02 | lambda_mmd 1.00e-05 | policy return -0.7224 | mean reward -0.0029 | position error 0.2224 m | 4.6 s
# Round  200/10000 | buffer  153600 groups | new 768 groups/58880 targets | L_dyn 5.5138e-06 | L_mmd 6.0210e-02 | lambda_mmd 1.00e-05 | policy return -0.7519 | mean reward -0.0030 | position error 0.2279 m | 4.6 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0200
# Round  201/10000 | buffer  154368 groups | new 768 groups/58880 targets | L_dyn 1.0349e-05 | L_mmd 5.6395e-02 | lambda_mmd 1.00e-05 | policy return -0.7619 | mean reward -0.0030 | position error 0.2263 m | 4.6 s
# Round  202/10000 | buffer  155136 groups | new 768 groups/58880 targets | L_dyn 8.0423e-06 | L_mmd 5.7093e-02 | lambda_mmd 1.00e-05 | policy return -0.7515 | mean reward -0.0030 | position error 0.2247 m | 4.6 s
# Round  203/10000 | buffer  155904 groups | new 768 groups/58880 targets | L_dyn 8.8444e-06 | L_mmd 6.8191e-02 | lambda_mmd 1.00e-05 | policy return -0.7110 | mean reward -0.0028 | position error 0.2173 m | 4.6 s
# Round  204/10000 | buffer  156672 groups | new 768 groups/58880 targets | L_dyn 1.0777e-05 | L_mmd 6.4185e-02 | lambda_mmd 1.00e-05 | policy return -0.7511 | mean reward -0.0030 | position error 0.2272 m | 4.7 s
# Round  205/10000 | buffer  157440 groups | new 768 groups/58880 targets | L_dyn 6.0517e-06 | L_mmd 6.4999e-02 | lambda_mmd 1.00e-05 | policy return -0.7728 | mean reward -0.0031 | position error 0.2293 m | 4.6 s
# Round  206/10000 | buffer  158208 groups | new 768 groups/58880 targets | L_dyn 6.9657e-06 | L_mmd 6.0613e-02 | lambda_mmd 1.00e-05 | policy return -0.7103 | mean reward -0.0028 | position error 0.2203 m | 4.7 s
# Round  207/10000 | buffer  158976 groups | new 768 groups/58880 targets | L_dyn 2.2988e-05 | L_mmd 5.6494e-02 | lambda_mmd 1.00e-05 | policy return -0.7467 | mean reward -0.0030 | position error 0.2239 m | 4.7 s
# Round  208/10000 | buffer  159744 groups | new 768 groups/58880 targets | L_dyn 4.9776e-06 | L_mmd 6.0761e-02 | lambda_mmd 1.00e-05 | policy return -0.7435 | mean reward -0.0030 | position error 0.2250 m | 4.6 s
# Round  209/10000 | buffer  160512 groups | new 768 groups/58880 targets | L_dyn 1.0695e-05 | L_mmd 5.9888e-02 | lambda_mmd 1.00e-05 | policy return -0.7438 | mean reward -0.0030 | position error 0.2236 m | 4.6 s
# Round  210/10000 | buffer  161280 groups | new 768 groups/58880 targets | L_dyn 5.9979e-06 | L_mmd 6.5326e-02 | lambda_mmd 1.00e-05 | policy return -0.7333 | mean reward -0.0029 | position error 0.2219 m | 4.7 s
# Round  211/10000 | buffer  162048 groups | new 768 groups/58880 targets | L_dyn 1.0459e-05 | L_mmd 5.9562e-02 | lambda_mmd 1.00e-05 | policy return -0.7225 | mean reward -0.0029 | position error 0.2207 m | 4.6 s
# Round  212/10000 | buffer  162816 groups | new 768 groups/58880 targets | L_dyn 6.6606e-06 | L_mmd 6.3043e-02 | lambda_mmd 1.00e-05 | policy return -0.7318 | mean reward -0.0029 | position error 0.2251 m | 4.7 s
# Round  213/10000 | buffer  163584 groups | new 768 groups/58880 targets | L_dyn 8.0843e-06 | L_mmd 5.9962e-02 | lambda_mmd 1.00e-05 | policy return -0.7552 | mean reward -0.0030 | position error 0.2266 m | 4.6 s
# Round  214/10000 | buffer  164352 groups | new 768 groups/58880 targets | L_dyn 1.0041e-05 | L_mmd 6.4249e-02 | lambda_mmd 1.00e-05 | policy return -0.7169 | mean reward -0.0029 | position error 0.2201 m | 4.6 s
# Round  215/10000 | buffer  165120 groups | new 768 groups/58880 targets | L_dyn 4.2483e-06 | L_mmd 6.5208e-02 | lambda_mmd 1.00e-05 | policy return -0.7308 | mean reward -0.0029 | position error 0.2229 m | 4.6 s
# Round  216/10000 | buffer  165888 groups | new 768 groups/58880 targets | L_dyn 9.7313e-06 | L_mmd 6.1247e-02 | lambda_mmd 1.00e-05 | policy return -0.7494 | mean reward -0.0030 | position error 0.2258 m | 4.6 s
# Round  217/10000 | buffer  166656 groups | new 768 groups/58880 targets | L_dyn 9.4446e-06 | L_mmd 6.2375e-02 | lambda_mmd 1.00e-05 | policy return -0.7714 | mean reward -0.0031 | position error 0.2282 m | 4.6 s
# Round  218/10000 | buffer  167424 groups | new 768 groups/58880 targets | L_dyn 6.4917e-06 | L_mmd 6.5496e-02 | lambda_mmd 1.00e-05 | policy return -0.7435 | mean reward -0.0030 | position error 0.2229 m | 4.7 s
# Round  219/10000 | buffer  168192 groups | new 768 groups/58880 targets | L_dyn 9.3232e-06 | L_mmd 6.0972e-02 | lambda_mmd 1.00e-05 | policy return -0.7245 | mean reward -0.0029 | position error 0.2234 m | 4.6 s
# Round  220/10000 | buffer  168960 groups | new 768 groups/58880 targets | L_dyn 7.4947e-06 | L_mmd 6.1574e-02 | lambda_mmd 1.00e-05 | policy return -0.7463 | mean reward -0.0030 | position error 0.2271 m | 4.7 s
# Round  221/10000 | buffer  169728 groups | new 768 groups/58880 targets | L_dyn 5.7116e-06 | L_mmd 5.3409e-02 | lambda_mmd 1.00e-05 | policy return -0.7145 | mean reward -0.0029 | position error 0.2224 m | 4.6 s
# ...
# Round  513/10000 | buffer  393984 groups | new 768 groups/58880 targets | L_dyn 4.8899e-06 | L_mmd 6.1617e-02 | lambda_mmd 1.00e-05 | policy return -0.7327 | mean reward -0.0029 | position error 0.2220 m | 4.8 s
# Round  514/10000 | buffer  394752 groups | new 768 groups/58880 targets | L_dyn 2.6227e-06 | L_mmd 5.7103e-02 | lambda_mmd 1.00e-05 | policy return -0.7223 | mean reward -0.0029 | position error 0.2188 m | 4.7 s
# Round  515/10000 | buffer  395520 groups | new 768 groups/58880 targets | L_dyn 2.6878e-06 | L_mmd 5.9056e-02 | lambda_mmd 1.00e-05 | policy return -0.7222 | mean reward -0.0029 | position error 0.2221 m | 4.7 s
# Round  516/10000 | buffer  396288 groups | new 768 groups/58880 targets | L_dyn 6.5630e-06 | L_mmd 6.0600e-02 | lambda_mmd 1.00e-05 | policy return -0.7291 | mean reward -0.0029 | position error 0.2231 m | 4.7 s
# Round  517/10000 | buffer  397056 groups | new 768 groups/58880 targets | L_dyn 4.8442e-06 | L_mmd 5.4823e-02 | lambda_mmd 1.00e-05 | policy return -0.7285 | mean reward -0.0029 | position error 0.2205 m | 4.7 s
# Round  518/10000 | buffer  397824 groups | new 768 groups/58880 targets | L_dyn 2.4801e-06 | L_mmd 6.0247e-02 | lambda_mmd 1.00e-05 | policy return -0.7402 | mean reward -0.0030 | position error 0.2246 m | 4.6 s
# Round  519/10000 | buffer  398592 groups | new 768 groups/58880 targets | L_dyn 4.3907e-06 | L_mmd 6.5036e-02 | lambda_mmd 1.00e-05 | policy return -0.7263 | mean reward -0.0029 | position error 0.2203 m | 4.8 s
# Round  520/10000 | buffer  399360 groups | new 768 groups/58880 targets | L_dyn 2.2250e-06 | L_mmd 6.5168e-02 | lambda_mmd 1.00e-05 | policy return -0.7111 | mean reward -0.0028 | position error 0.2180 m | 4.7 s
# Round  521/10000 | buffer  400128 groups | new 768 groups/58880 targets | L_dyn 3.4196e-06 | L_mmd 6.1864e-02 | lambda_mmd 1.00e-05 | policy return -0.7228 | mean reward -0.0029 | position error 0.2206 m | 4.9 s
# Round  522/10000 | buffer  400896 groups | new 768 groups/58880 targets | L_dyn 3.3706e-06 | L_mmd 6.4712e-02 | lambda_mmd 1.00e-05 | policy return -0.7285 | mean reward -0.0029 | position error 0.2228 m | 4.7 s
# Round  523/10000 | buffer  401664 groups | new 768 groups/58880 targets | L_dyn 3.5538e-06 | L_mmd 5.7338e-02 | lambda_mmd 1.00e-05 | policy return -0.7478 | mean reward -0.0030 | position error 0.2249 m | 4.8 s
# Round  524/10000 | buffer  402432 groups | new 768 groups/58880 targets | L_dyn 3.5421e-06 | L_mmd 6.2704e-02 | lambda_mmd 1.00e-05 | policy return -0.7352 | mean reward -0.0029 | position error 0.2227 m | 4.7 s
# Round  525/10000 | buffer  403200 groups | new 768 groups/58880 targets | L_dyn 2.7745e-06 | L_mmd 6.1668e-02 | lambda_mmd 1.00e-05 | policy return -0.7377 | mean reward -0.0030 | position error 0.2238 m | 4.9 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0525
# Round  526/10000 | buffer  403968 groups | new 768 groups/58880 targets | L_dyn 2.5626e-06 | L_mmd 6.1434e-02 | lambda_mmd 1.00e-05 | policy return -0.7181 | mean reward -0.0029 | position error 0.2199 m | 4.7 s
# Round  527/10000 | buffer  404736 groups | new 768 groups/58880 targets | L_dyn 3.3274e-06 | L_mmd 6.0940e-02 | lambda_mmd 1.00e-05 | policy return -0.7102 | mean reward -0.0028 | position error 0.2170 m | 4.7 s
# Round  528/10000 | buffer  405504 groups | new 768 groups/58880 targets | L_dyn 2.2778e-06 | L_mmd 6.1578e-02 | lambda_mmd 1.00e-05 | policy return -0.7353 | mean reward -0.0029 | position error 0.2240 m | 4.7 s
# Round  529/10000 | buffer  406272 groups | new 768 groups/58880 targets | L_dyn 2.5416e-06 | L_mmd 6.4653e-02 | lambda_mmd 1.00e-05 | policy return -0.7174 | mean reward -0.0029 | position error 0.2175 m | 4.8 s
# Round  530/10000 | buffer  407040 groups | new 768 groups/58880 targets | L_dyn 1.5215e-06 | L_mmd 6.3416e-02 | lambda_mmd 1.00e-05 | policy return -0.7234 | mean reward -0.0029 | position error 0.2191 m | 4.7 s
# Round  531/10000 | buffer  407808 groups | new 768 groups/58880 targets | L_dyn 2.3466e-06 | L_mmd 5.9541e-02 | lambda_mmd 1.00e-05 | policy return -0.7294 | mean reward -0.0029 | position error 0.2217 m | 4.7 s
# Round  532/10000 | buffer  408576 groups | new 768 groups/58880 targets | L_dyn 2.8359e-06 | L_mmd 5.8779e-02 | lambda_mmd 1.00e-05 | policy return -0.7325 | mean reward -0.0029 | position error 0.2232 m | 4.7 s
# Round  533/10000 | buffer  409344 groups | new 768 groups/58880 targets | L_dyn 1.0745e-05 | L_mmd 5.7009e-02 | lambda_mmd 1.00e-05 | policy return -0.7157 | mean reward -0.0029 | position error 0.2209 m | 4.8 s
# Round  534/10000 | buffer  410112 groups | new 768 groups/58880 targets | L_dyn 3.6583e-06 | L_mmd 6.0737e-02 | lambda_mmd 1.00e-05 | policy return -0.7016 | mean reward -0.0028 | position error 0.2198 m | 4.8 s
# Round  535/10000 | buffer  410880 groups | new 768 groups/58880 targets | L_dyn 1.3553e-06 | L_mmd 5.6156e-02 | lambda_mmd 1.00e-05 | policy return -0.7287 | mean reward -0.0029 | position error 0.2262 m | 4.7 s
# Round  536/10000 | buffer  411648 groups | new 768 groups/58880 targets | L_dyn 3.0616e-06 | L_mmd 6.0836e-02 | lambda_mmd 1.00e-05 | policy return -0.7297 | mean reward -0.0029 | position error 0.2249 m | 4.9 s
# Round  537/10000 | buffer  412416 groups | new 768 groups/58880 targets | L_dyn 4.1250e-06 | L_mmd 6.2669e-02 | lambda_mmd 1.00e-05 | policy return -0.7058 | mean reward -0.0028 | position error 0.2175 m | 5.3 s
# Round  538/10000 | buffer  413184 groups | new 768 groups/58880 targets | L_dyn 3.5591e-06 | L_mmd 6.6078e-02 | lambda_mmd 1.00e-05 | policy return -0.7383 | mean reward -0.0030 | position error 0.2217 m | 5.2 s
# Round  539/10000 | buffer  413952 groups | new 768 groups/58880 targets | L_dyn 2.4975e-06 | L_mmd 6.0114e-02 | lambda_mmd 1.00e-05 | policy return -0.7198 | mean reward -0.0029 | position error 0.2204 m | 5.1 s
# Round  540/10000 | buffer  414720 groups | new 768 groups/58880 targets | L_dyn 3.8271e-06 | L_mmd 6.5259e-02 | lambda_mmd 1.00e-05 | policy return -0.7026 | mean reward -0.0028 | position error 0.2189 m | 5.3 s
# Round  541/10000 | buffer  415488 groups | new 768 groups/58880 targets | L_dyn 4.6891e-06 | L_mmd 5.9153e-02 | lambda_mmd 1.00e-05 | policy return -0.7145 | mean reward -0.0029 | position error 0.2188 m | 5.4 s
# Round  542/10000 | buffer  416256 groups | new 768 groups/58880 targets | L_dyn 1.9505e-06 | L_mmd 5.6463e-02 | lambda_mmd 1.00e-05 | policy return -0.7121 | mean reward -0.0028 | position error 0.2228 m | 5.2 s
# Round  543/10000 | buffer  417024 groups | new 768 groups/58880 targets | L_dyn 2.4420e-06 | L_mmd 6.8421e-02 | lambda_mmd 1.00e-05 | policy return -0.7295 | mean reward -0.0029 | position error 0.2254 m | 5.3 s
# Round  544/10000 | buffer  417792 groups | new 768 groups/58880 targets | L_dyn 2.7392e-06 | L_mmd 5.9555e-02 | lambda_mmd 1.00e-05 | policy return -0.7298 | mean reward -0.0029 | position error 0.2243 m | 5.2 s
# Round  545/10000 | buffer  418560 groups | new 768 groups/58880 targets | L_dyn 2.5803e-06 | L_mmd 5.9972e-02 | lambda_mmd 1.00e-05 | policy return -0.7317 | mean reward -0.0029 | position error 0.2256 m | 5.5 s
# Round  546/10000 | buffer  419328 groups | new 768 groups/58880 targets | L_dyn 2.0958e-06 | L_mmd 5.6397e-02 | lambda_mmd 1.00e-05 | policy return -0.7315 | mean reward -0.0029 | position error 0.2233 m | 5.1 s
# Round  547/10000 | buffer  420096 groups | new 768 groups/58880 targets | L_dyn 2.4986e-06 | L_mmd 6.1095e-02 | lambda_mmd 1.00e-05 | policy return -0.7382 | mean reward -0.0030 | position error 0.2269 m | 5.2 s
# Round  548/10000 | buffer  420864 groups | new 768 groups/58880 targets | L_dyn 3.9023e-06 | L_mmd 5.5986e-02 | lambda_mmd 1.00e-05 | policy return -0.7380 | mean reward -0.0030 | position error 0.2253 m | 5.2 s
# Round  549/10000 | buffer  421632 groups | new 768 groups/58880 targets | L_dyn 3.5778e-06 | L_mmd 5.9422e-02 | lambda_mmd 1.00e-05 | policy return -0.7436 | mean reward -0.0030 | position error 0.2236 m | 5.2 s
# Round  550/10000 | buffer  422400 groups | new 768 groups/58880 targets | L_dyn 2.9530e-06 | L_mmd 5.5719e-02 | lambda_mmd 1.00e-05 | policy return -0.7213 | mean reward -0.0029 | position error 0.2205 m | 5.1 s
#   checkpoint: /home/dimitria/PhD_codes/learning_on_the_fly/checkpoints/continual_vnd/state_hovering_full/round_0550
# Round  551/10000 | buffer  423168 groups | new 768 groups/58880 targets | L_dyn 2.2900e-06 | L_mmd 6.2295e-02 | lambda_mmd 1.00e-05 | policy return -0.7507 | mean reward -0.0030 | position error 0.2263 m | 5.2 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 115
#     111     # Stage 1C: train from accumulated replay, even when this round did
#     112     # not add data. If replay is empty, skip only Stage 1C.
#     113     dynamics_stage_ran = replay_buffer.num_groups > 0
#     114     if dynamics_stage_ran:
# --> 115         joint_train_state, dynamics_metrics = run_dynamics_stage(
#     116             joint_train_state,
#     117             replay_buffer,
#     118             fixed_prior_bank,
#
# Cell In[9], line 153, in run_dynamics_stage(train_state, replay, fixed_prior_bank, input_mean, input_std, target_mean, target_std, first_global_update, stage_key)
#     149         global_update = first_global_update + local_update
#     150         batch_key = jax.random.fold_in(stage_key, local_update)
#     151         batch = replay.sample(batch_key, replay_batch_size)
#     152         prior_indices = (
# --> 153             jnp.arange(replay_batch_size)
#     154             + global_update * replay_batch_size
#     155         ) % fixed_prior_bank.shape[0]
#     156         prior_latents = fixed_prior_bank[prior_indices]
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/jax/_src/numpy/lax_numpy.py:3538, in arange(start, stop, step, dtype)
#    3534   dtypes.check_user_dtype_supported(dtype, "identity")
#    3535   return eye(n, dtype=dtype)
# -> 3538 @util.implements(np.arange,lax_description= """
#    3539 .. note::
#    3540
#    3541    Using ``arange`` with the ``step`` argument can lead to precision errors,
#    3542    especially with lower-precision data types like ``fp8`` and ``bf16``.
#    3543    For more details, see the docstring of :func:`numpy.arange`.
#    3544    To avoid precision errors, consider using an expression like
#    3545    ``(jnp.arange(-600, 600) * .01).astype(jnp.bfloat16)`` to generate a sequence in a higher precision
#    3546    and then convert it to the desired lower precision.
#    3547 """)
#    3548 def arange(start: DimSize, stop: DimSize | None = None,
#    3549            step: DimSize | None = None, dtype: DTypeLike | None = None) -> Array:
#    3550   dtypes.check_user_dtype_supported(dtype, "arange")
#    3551   if not config.dynamic_shapes.value:
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7806740359d0>> (for post_run_cell), with arguments args (<ExecutionResult object at 78058813ce00, execution_count=12 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 78058813e7b0, raw_cell="input_mean = startup_input_mean
# input_std = startu.." transformed_cell="input_mean = startup_input_mean
# input_std = startu.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/home/dimitria/PhD_codes/learning_on_the_fly/examples/state_hovering/train_residual_dyn_full.ipynb#X32sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:625, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     622     return
#     624 self._logger.info("resuming backend")
# --> 625 self._interface.publish_resume()
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:835, in InterfaceBase.publish_resume(self)
#     833 def publish_resume(self) -> None:
#     834     resume = pb.ResumeRequest()
# --> 835     self._publish_resume(resume)
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:344, in InterfaceShared._publish_resume(self, resume)
#     342 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     343     rec = self._make_request(resume=resume)
# --> 344     self._publish(rec)
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:145, in AsyncioManager.run(self, fn)
#     142 future = self._schedule(fn, daemon=False)
#     144 try:
# --> 145     return future.result()
#     147 except concurrent.futures.CancelledError:
#     148     raise RunCancelledError from None
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:238, in AsyncioManager._wrap(self, fn, daemon, name)
#     235     if name and (task := asyncio.current_task()):
#     236         task.set_name(name)
# --> 238     return await fn()
#     239 finally:
#     240     if not daemon:
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:42, in ServiceClient.publish(self, request)
#      40 async def publish(self, request: spb.ServerRequest) -> None:
#      41     """Send a request without waiting for a response."""
# ---> 42     await self._send_server_request(request)
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:84, in ServiceClient._send_server_request(self, request)
#      81 self._writer.write(data)
#      83 try:
# ---> 84     await self._drain_writer()
#      85 except Exception as e:
#      86     self._broken_exc = e
#
# File ~/venvs/diff-sim-env/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:92, in ServiceClient._drain_writer(self)
#      90 async def _drain_writer(self) -> None:
#      91     """Wait for the socket's flow control."""
# ---> 92     await self._writer.drain()
#
# File /usr/lib/python3.12/asyncio/streams.py:392, in StreamWriter.drain(self)
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)    389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
# --> 392 await self._protocol._drain_helper()
#
# File /usr/lib/python3.12/asyncio/streams.py:166, in FlowControlMixin._drain_helper(self)
#     164 async def _drain_helper(self):
#     165     if self._connection_lost:
# --> 166         raise ConnectionResetError('Connection lost')
#     167     if not self._paused:
#     168         return
#
# ConnectionResetError: Connection lost

# %% [markdown]
# ## 12. Training curves and sampled-latent sanity check
#
# These plots report optimizer objectives, not held-out dynamics validation. The final print checks only the marginal mean and standard deviation of the sampled Stage-2 prior bank; MMD alignment of encoded latents should be evaluated separately on encoded buffer contexts.

# %%
dynamics_update_axis = np.arange(len(training_history["dynamics_loss"]))
round_axis = np.arange(1, len(training_history["policy_loss"]) + 1)

fig, axes = plt.subplots(2, 2, figsize=(13, 8))
axes[0, 0].plot(dynamics_update_axis, training_history["dynamics_loss"])
axes[0, 0].set(title="VND dynamics loss", xlabel="Dynamics update", ylabel="L_dyn")
axes[0, 0].grid(alpha=0.3)

axes[0, 1].plot(dynamics_update_axis, training_history["mmd_loss"], label="L_mmd")
axes[0, 1].plot(dynamics_update_axis, training_history["mmd_weight"], label="lambda_mmd")
axes[0, 1].set(title="Prior alignment", xlabel="Dynamics update")
axes[0, 1].legend()
axes[0, 1].grid(alpha=0.3)

axes[1, 0].plot(round_axis, training_history["policy_return"])
axes[1, 0].set(title="BPTT policy return", xlabel="Continual round", ylabel="Mean return")
axes[1, 0].grid(alpha=0.3)

axes[1, 1].plot(round_axis, training_history["policy_position_error"])
axes[1, 1].set(
    title="BPTT mean Euclidean position error",
    xlabel="Continual round",
    ylabel="Position error [m]",
)
axes[1, 1].grid(alpha=0.3)
plt.tight_layout()
plt.show()

final_prior_mean = fixed_prior_bank.mean(axis=0)
final_prior_std = fixed_prior_bank.std(axis=0)
print("Final Stage-2 sampled prior bank:")
print(f"  mean per latent dimension: {final_prior_mean}")
print(f"  std per latent dimension:  {final_prior_std}")
print(f"  aggregate mean: {final_prior_mean.mean():.4f}")
print(f"  aggregate std:  {final_prior_std.mean():.4f}")
